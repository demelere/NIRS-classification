# %%
import os
import sys
import numpy as np
from pathlib import Path

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from modules.snirf_reader import read_snirf

# %%
snirf_file = Path("../data/2021_08-Finger_Tapping-Hb.snirf")

# %%
data_nirs, timestamps, measurement_names, df_events = read_snirf(snirf_file)

# %%
print("Data NIRS shape:", data_nirs.shape)
print("Timestamps:", timestamps)
print("Measurement names:", measurement_names)
print("Event DataFrame:")
print(df_events)
# Out:
# Data NIRS shape: (6436, 4412)
# Timestamps: [  2.30570364   2.42682052   2.54793763 ... 781.45061088 781.57172775
#  781.69284463]
# Measurement names: ['S01_D01d1 HbO', 'S01_D01d1 HbR', 'S01_D01d2 HbO', 'S01_D01d2 HbR', 'S01_D01d3 HbO', 'S01_D01d3 HbR', 'S01_D01d4 HbO', 'S01_D01d4 HbR', 'S01_D01d5 HbO', 'S01_D01d5 HbR', 'S01_D01d0 HbO', 'S01_D01d0 HbR', 'S01_D03d5 HbO', 'S01_D03d5 HbR', 'S01_D03d0 HbO', 'S01_D03d0 HbR', 'S01_D03d1 HbO', 'S01_D03d1 HbR', 'S01_D03d2 HbO', 'S01_D03d2 HbR', 'S01_D03d3 HbO', 'S01_D03d3 HbR', 'S01_D03d4 HbO', 'S01_D03d4 HbR', 'S01_D05d1 HbO', 'S01_D05d1 HbR', 'S01_D05d2 HbO', 'S01_D05d2 HbR', 'S01_D05d3 HbO', 'S01_D05d3 HbR', 'S01_D05d4 HbO', 'S01_D05d4 HbR', 'S01_D05d5 HbO', 'S01_D05d5 HbR', 'S01_D05d0 HbO', 'S01_D05d0 HbR', 'S01_D07d5 HbO', 'S01_D07d5 HbR', 'S01_D07d0 HbO', 'S01_D07d0 HbR', 'S01_D07d3 HbO', 'S01_D07d3 HbR', 'S01_D07d4 HbO', 'S01_D07d4 HbR', 'S01_D09d2 HbO', 'S01_D09d2 HbR', 'S01_D09d3 HbO', 'S01_D09d3 HbR', 'S01_D09d4 HbO', 'S01_D09d4 HbR', 'S01_D09d1 HbO', 'S01_D09d1 HbR', 'S01_D11d3 HbO', 'S01_D11d3 HbR', 'S01_D11d4 HbO', 'S01_D11d4 HbR', 'S01_D11d2 HbO', 'S01_D11d2 HbR', 'S01_D00d1 HbO', 'S01_D00d1 HbR', 'S01_D00d3 HbO', 'S01_D00d3 HbR', 'S01_D00d2 HbO', 'S01_D00d2 HbR', 'S01_D08d1 HbO', 'S01_D08d1 HbR', 'S03_D01d1 HbO', 'S03_D01d1 HbR', 'S03_D01d2 HbO', 'S03_D01d2 HbR', 'S03_D01d3 HbO', 'S03_D01d3 HbR', 'S03_D01d4 HbO', 'S03_D01d4 HbR', 'S03_D01d5 HbO', 'S03_D01d5 HbR', 'S03_D01d0 HbO', 'S03_D01d0 HbR', 'S03_D03d5 HbO', 'S03_D03d5 HbR', 'S03_D03d0 HbO', 'S03_D03d0 HbR', 'S03_D03d1 HbO', 'S03_D03d1 HbR', 'S03_D03d2 HbO', 'S03_D03d2 HbR', 'S03_D03d3 HbO', 'S03_D03d3 HbR', 'S03_D03d4 HbO', 'S03_D03d4 HbR', 'S03_D05d1 HbO', 'S03_D05d1 HbR', 'S03_D05d2 HbO', 'S03_D05d2 HbR', 'S03_D05d3 HbO', 'S03_D05d3 HbR', 'S03_D05d4 HbO', 'S03_D05d4 HbR', 'S03_D05d5 HbO', 'S03_D05d5 HbR', 'S03_D05d0 HbO', 'S03_D05d0 HbR', 'S03_D07d5 HbO', 'S03_D07d5 HbR', 'S03_D07d0 HbO', 'S03_D07d0 HbR', 'S03_D07d1 HbO', 'S03_D07d1 HbR', 'S03_D07d2 HbO', 'S03_D07d2 HbR', 'S03_D07d3 HbO', 'S03_D07d3 HbR', 'S03_D07d4 HbO', 'S03_D07d4 HbR', 'S03_D09d2 HbO', 'S03_D09d2 HbR', 'S03_D09d3 HbO', 'S03_D09d3 HbR', 'S03_D09d4 HbO', 'S03_D09d4 HbR', 'S03_D11d3 HbO', 'S03_D11d3 HbR', 'S03_D11d4 HbO', 'S03_D11d4 HbR', 'S03_D11d5 HbO', 'S03_D11d5 HbR', 'S03_D11d2 HbO', 'S03_D11d2 HbR', 'S03_D19d2 HbO', 'S03_D19d2 HbR', 'S03_D19d3 HbO', 'S03_D19d3 HbR', 'S03_D19d4 HbO', 'S03_D19d4 HbR', 'S03_D19d5 HbO', 'S03_D19d5 HbR', 'S03_D19d0 HbO', 'S03_D19d0 HbR', 'S03_D19d1 HbO', 'S03_D19d1 HbR', 'S05_D01d1 HbO', 'S05_D01d1 HbR', 'S05_D01d2 HbO', 'S05_D01d2 HbR', 'S05_D01d3 HbO', 'S05_D01d3 HbR', 'S05_D01d4 HbO', 'S05_D01d4 HbR', 'S05_D01d5 HbO', 'S05_D01d5 HbR', 'S05_D01d0 HbO', 'S05_D01d0 HbR', 'S05_D03d5 HbO', 'S05_D03d5 HbR', 'S05_D03d0 HbO', 'S05_D03d0 HbR', 'S05_D03d1 HbO', 'S05_D03d1 HbR', 'S05_D03d2 HbO', 'S05_D03d2 HbR', 'S05_D03d3 HbO', 'S05_D03d3 HbR', 'S05_D03d4 HbO', 'S05_D03d4 HbR', 'S05_D05d1 HbO', 'S05_D05d1 HbR', 'S05_D05d2 HbO', 'S05_D05d2 HbR', 'S05_D05d3 HbO', 'S05_D05d3 HbR', 'S05_D05d4 HbO', 'S05_D05d4 HbR', 'S05_D05d5 HbO', 'S05_D05d5 HbR', 'S05_D05d0 HbO', 'S05_D05d0 HbR', 'S05_D07d5 HbO', 'S05_D07d5 HbR', 'S05_D07d0 HbO', 'S05_D07d0 HbR', 'S05_D07d1 HbO', 'S05_D07d1 HbR', 'S05_D07d2 HbO', 'S05_D07d2 HbR', 'S05_D07d3 HbO', 'S05_D07d3 HbR', 'S05_D07d4 HbO', 'S05_D07d4 HbR', 'S05_D09d2 HbO', 'S05_D09d2 HbR', 'S05_D09d3 HbO', 'S05_D09d3 HbR', 'S05_D09d4 HbO', 'S05_D09d4 HbR', 'S05_D09d5 HbO', 'S05_D09d5 HbR', 'S05_D09d0 HbO', 'S05_D09d0 HbR', 'S05_D09d1 HbO', 'S05_D09d1 HbR', 'S05_D11d3 HbO', 'S05_D11d3 HbR', 'S05_D11d4 HbO', 'S05_D11d4 HbR', 'S05_D11d5 HbO', 'S05_D11d5 HbR', 'S05_D11d0 HbO', 'S05_D11d0 HbR', 'S05_D11d1 HbO', 'S05_D11d1 HbR', 'S05_D11d2 HbO', 'S05_D11d2 HbR', 'S05_D19d2 HbO', 'S05_D19d2 HbR', 'S05_D19d1 HbO', 'S05_D19d1 HbR', 'S05_D08d0 HbO', 'S05_D08d0 HbR', 'S05_D08d2 HbO', 'S05_D08d2 HbR', 'S05_D08d1 HbO', 'S05_D08d1 HbR', 'S07_D01d2 HbO', 'S07_D01d2 HbR', 'S07_D01d3 HbO', 'S07_D01d3 HbR', 'S07_D01d4 HbO', 'S07_D01d4 HbR', 'S07_D01d5 HbO', 'S07_D01d5 HbR', 'S07_D03d5 HbO', 'S07_D03d5 HbR', 'S07_D03d0 HbO', 'S07_D03d0 HbR', 'S ...
# Event DataFrame:
#       Timestamp            Event    Duration  Value  Block  Trial BlockType  \
# 0      3.217344  StartExperiment  777.508700    1.0    NaN    NaN       NaN
# 1      3.307724        StartRest   20.018198    1.0    NaN    NaN       NaN
# 2     23.326003       StartBlock   17.731031    1.0    1.0    NaN     Right
# 3     23.374841         StartIti    0.262291    1.0    1.0    NaN     Right
# 4     23.637193       StartTrial    0.790963    1.0    1.0    1.0     Right
# ..          ...              ...         ...    ...    ...    ...       ...
# 577  757.754821       StartTrial    0.805964    1.0   20.0  259.0      Left
# 578  758.607495         StartIti    0.605608    1.0   20.0    NaN      Left
# 579  759.213161       StartTrial    0.778275    1.0   20.0  260.0      Left
# 580  760.040823         StartIti    0.585636    1.0   20.0    NaN      Left
# 581  760.707564        StartRest   20.018397    1.0    NaN    NaN       NaN
#
#     TrialType ExperimentType
# 0         NaN  FingerTapping
# 1         NaN  FingerTapping
# 2         NaN  FingerTapping
# 3         NaN  FingerTapping
# 4       Pinky  FingerTapping
# ..        ...            ...
# 577    Middle  FingerTapping
# 578       NaN  FingerTapping
# 579      Ring  FingerTapping
# 580       NaN  FingerTapping
# 581       NaN  FingerTapping
#
# [582 rows x 9 columns]

# %%
# Get unique channel names
channel_names = [name.split()[0] for name in measurement_names]
unique_channels = set(channel_names)

# Get unique chromophores
chromophores = [name.split()[-1] for name in measurement_names]
unique_chromophores = set(chromophores)

# Print the counts
print("Number of unique channels:", len(unique_channels))
print("Number of unique chromophores:", len(unique_chromophores))
# Out:
# Number of unique channels: 2206
# Number of unique chromophores: 2

# %%
# Calculate the 3D shape
timestamps_count = data_nirs.shape[0]
channels_count = len(unique_channels)
chromophores_count = len(unique_chromophores)

shape_3d = (timestamps_count, channels_count, chromophores_count)

# Print the 3D shape
print("3D shape:", shape_3d)
# Out:
# 3D shape: (6436, 2206, 2)

# %%
unique_channels = list(set(channel_names))
unique_chromophores = list(set(chromophores))

# Sort the lists in alphabetical order
unique_channels.sort()
unique_chromophores.sort()

# Print the sorted lists
print("Unique channels (sorted):", unique_channels)
print("Unique chromophores (sorted):", unique_chromophores)
# Out:
# Unique channels (sorted): ['S00_D00d0', 'S00_D00d1', 'S00_D00d2', 'S00_D00d3', 'S00_D00d4', 'S00_D00d5', 'S00_D01d0', 'S00_D01d1', 'S00_D01d5', 'S00_D02d0', 'S00_D02d1', 'S00_D02d2', 'S00_D02d3', 'S00_D02d4', 'S00_D02d5', 'S00_D04d0', 'S00_D04d1', 'S00_D04d2', 'S00_D04d3', 'S00_D04d4', 'S00_D04d5', 'S00_D06d2', 'S00_D06d3', 'S00_D06d4', 'S00_D06d5', 'S00_D08d0', 'S00_D08d1', 'S00_D08d4', 'S00_D08d5', 'S00_D09d1', 'S00_D10d0', 'S00_D10d4', 'S00_D10d5', 'S01_D00d1', 'S01_D00d2', 'S01_D00d3', 'S01_D01d0', 'S01_D01d1', 'S01_D01d2', 'S01_D01d3', 'S01_D01d4', 'S01_D01d5', 'S01_D03d0', 'S01_D03d1', 'S01_D03d2', 'S01_D03d3', 'S01_D03d4', 'S01_D03d5', 'S01_D05d0', 'S01_D05d1', 'S01_D05d2', 'S01_D05d3', 'S01_D05d4', 'S01_D05d5', 'S01_D07d0', 'S01_D07d3', 'S01_D07d4', 'S01_D07d5', 'S01_D08d1', 'S01_D09d1', 'S01_D09d2', 'S01_D09d3', 'S01_D09d4', 'S01_D11d2', 'S01_D11d3', 'S01_D11d4', 'S02_D00d0', 'S02_D00d1', 'S02_D00d2', 'S02_D00d3', 'S02_D00d4', 'S02_D00d5', 'S02_D02d0', 'S02_D02d1', 'S02_D02d2', 'S02_D02d3', 'S02_D02d4', 'S02_D02d5', 'S02_D04d0', 'S02_D04d1', 'S02_D04d2', 'S02_D04d3', 'S02_D04d4', 'S02_D04d5', 'S02_D06d0', 'S02_D06d1', 'S02_D06d2', 'S02_D06d3', 'S02_D06d4', 'S02_D06d5', 'S02_D08d0', 'S02_D08d4', 'S02_D08d5', 'S02_D10d0', 'S02_D10d3', 'S02_D10d4', 'S02_D10d5', 'S02_D18d0', 'S02_D18d1', 'S02_D18d2', 'S02_D18d3', 'S02_D18d4', 'S02_D18d5', 'S03_D01d0', 'S03_D01d1', 'S03_D01d2', 'S03_D01d3', 'S03_D01d4', 'S03_D01d5', 'S03_D03d0', 'S03_D03d1', 'S03_D03d2', 'S03_D03d3', 'S03_D03d4', 'S03_D03d5', 'S03_D05d0', 'S03_D05d1', 'S03_D05d2', 'S03_D05d3', 'S03_D05d4', 'S03_D05d5', 'S03_D07d0', 'S03_D07d1', 'S03_D07d2', 'S03_D07d3', 'S03_D07d4', 'S03_D07d5', 'S03_D09d2', 'S03_D09d3', 'S03_D09d4', 'S03_D11d2', 'S03_D11d3', 'S03_D11d4', 'S03_D11d5', 'S03_D19d0', 'S03_D19d1', 'S03_D19d2', 'S03_D19d3', 'S03_D19d4', 'S03_D19d5', 'S04_D00d0', 'S04_D00d1', 'S04_D00d2', 'S04_D00d3', 'S04_D00d4', 'S04_D00d5', 'S04_D02d0', 'S04_D02d1', 'S04_D02d2', 'S04_D02d3', 'S04_D02d4', 'S04_D02d5', 'S04_D04d0', 'S04_D04d1', 'S04_D04d2', 'S04_D04d3', 'S04_D04d4', 'S04_D04d5', 'S04_D06d0', 'S04_D06d1', 'S04_D06d2', 'S04_D06d3', 'S04_D06d4', 'S04_D06d5', 'S04_D08d0', 'S04_D08d1', 'S04_D08d2', 'S04_D08d3', 'S04_D08d4', 'S04_D08d5', 'S04_D09d0', 'S04_D09d1', 'S04_D09d2', 'S04_D10d0', 'S04_D10d1', 'S04_D10d2', 'S04_D10d3', 'S04_D10d4', 'S04_D10d5', 'S04_D18d0', 'S04_D18d1', 'S05_D01d0', 'S05_D01d1', 'S05_D01d2', 'S05_D01d3', 'S05_D01d4', 'S05_D01d5', 'S05_D03d0', 'S05_D03d1', 'S05_D03d2', 'S05_D03d3', 'S05_D03d4', 'S05_D03d5', 'S05_D05d0', 'S05_D05d1', 'S05_D05d2', 'S05_D05d3', 'S05_D05d4', 'S05_D05d5', 'S05_D07d0', 'S05_D07d1', 'S05_D07d2', 'S05_D07d3', 'S05_D07d4', 'S05_D07d5', 'S05_D08d0', 'S05_D08d1', 'S05_D08d2', 'S05_D09d0', 'S05_D09d1', 'S05_D09d2', 'S05_D09d3', 'S05_D09d4', 'S05_D09d5', 'S05_D11d0', 'S05_D11d1', 'S05_D11d2', 'S05_D11d3', 'S05_D11d4', 'S05_D11d5', 'S05_D19d1', 'S05_D19d2', 'S06_D00d0', 'S06_D00d3', 'S06_D00d4', 'S06_D00d5', 'S06_D02d0', 'S06_D02d1', 'S06_D02d2', 'S06_D02d3', 'S06_D02d4', 'S06_D02d5', 'S06_D04d0', 'S06_D04d1', 'S06_D04d2', 'S06_D04d3', 'S06_D04d4', 'S06_D04d5', 'S06_D06d0', 'S06_D06d1', 'S06_D06d2', 'S06_D06d3', 'S06_D06d4', 'S06_D06d5', 'S06_D08d0', 'S06_D08d3', 'S06_D08d4', 'S06_D08d5', 'S06_D10d0', 'S06_D10d1', 'S06_D10d2', 'S06_D10d3', 'S06_D10d4', 'S06_D10d5', 'S06_D14d2', 'S06_D16d0', 'S06_D16d1', 'S06_D16d2', 'S06_D16d3', 'S06_D16d4', 'S06_D16d5', 'S06_D18d0', 'S06_D18d1', 'S06_D18d2', 'S06_D18d3', 'S06_D18d4', 'S06_D18d5', 'S06_D26d0', 'S06_D26d5', 'S07_D01d2', 'S07_D01d3', 'S07_D01d4', 'S07_D01d5', 'S07_D03d0', 'S07_D03d1', 'S07_D03d2', 'S07_D03d3', 'S07_D03d4', 'S07_D03d5', 'S07_D05d0', 'S07_D05d1', 'S07_D05d2', 'S07_D05d3', 'S07_D05d4', 'S07_D05d5', 'S07_D07d0', 'S07_D07d1', 'S07_D07d2', 'S07_D07d3', 'S07_D07d4', 'S07_D07d5', 'S07_D09d2', 'S07_D09d3', 'S07_D09d4', 'S07_D09d5', 'S07_D11d0', 'S07_D11d1', 'S07_D11d2', 'S07_D11d3', 'S07_D11d4', 'S07_D11d5', 'S07_D15d0', 'S07_D17d0', 'S07_D17d1', 'S07_D17d2', 'S07_D17 ...
# Unique chromophores (sorted): ['HbO', 'HbR']

# %%
# Find indices of channels and chromophores for each measurement
channel_indices = [unique_channels.index(name.split()[0]) for name in measurement_names]
chromophore_indices = [unique_chromophores.index(name.split()[-1]) for name in measurement_names]

# Print the indices for each measurement
for i, measurement in enumerate(measurement_names):
    print(f"Measurement: {measurement}")
    print(f"Channel Index: {channel_indices[i]}")
    print(f"Chromophore Index: {chromophore_indices[i]}")
    print()
# Out:
# Measurement: S01_D01d1 HbO
# Channel Index: 37
# Chromophore Index: 0
#
# Measurement: S01_D01d1 HbR
# Channel Index: 37
# Chromophore Index: 1
#
# Measurement: S01_D01d2 HbO
# Channel Index: 38
# Chromophore Index: 0
#
# Measurement: S01_D01d2 HbR
# Channel Index: 38
# Chromophore Index: 1
#
# Measurement: S01_D01d3 HbO
# Channel Index: 39
# Chromophore Index: 0
#
# Measurement: S01_D01d3 HbR
# Channel Index: 39
# Chromophore Index: 1
#
# Measurement: S01_D01d4 HbO
# Channel Index: 40
# Chromophore Index: 0
#
# Measurement: S01_D01d4 HbR
# Channel Index: 40
# Chromophore Index: 1
#
# Measurement: S01_D01d5 HbO
# Channel Index: 41
# Chromophore Index: 0
#
# Measurement: S01_D01d5 HbR
# Channel Index: 41
# Chromophore Index: 1
#
# Measurement: S01_D01d0 HbO
# Channel Index: 36
# Chromophore Index: 0
#
# Measurement: S01_D01d0 HbR
# Channel Index: 36
# Chromophore Index: 1
#
# Measurement: S01_D03d5 HbO
# Channel Index: 47
# Chromophore Index: 0
#
# Measurement: S01_D03d5 HbR
# Channel Index: 47
# Chromophore Index: 1
#
# Measurement: S01_D03d0 HbO
# Channel Index: 42
# Chromophore Index: 0
#
# Measurement: S01_D03d0 HbR
# Channel Index: 42
# Chromophore Index: 1
#
# Measurement: S01_D03d1 HbO
# Channel Index: 43
# Chromophore Index: 0
#
# Measurement: S01_D03d1 HbR
# Channel Index: 43
# Chromophore Index: 1
#
# Measurement: S01_D03d2 HbO
# Channel Index: 44
# Chromophore Index: 0
#
# Measurement: S01_D03d2 HbR
# Channel Index: 44
# Chromophore Index: 1
#
# Measurement: S01_D03d3 HbO
# Channel Index: 45
# Chromophore Index: 0
#
# Measurement: S01_D03d3 HbR
# Channel Index: 45
# Chromophore Index: 1
#
# Measurement: S01_D03d4 HbO
# Channel Index: 46
# Chromophore Index: 0
#
# Measurement: S01_D03d4 HbR
# Channel Index: 46
# Chromophore Index: 1
#
# Measurement: S01_D05d1 HbO
# Channel Index: 49
# Chromophore Index: 0
#
# Measurement: S01_D05d1 HbR
# Channel Index: 49
# Chromophore Index: 1
#
# Measurement: S01_D05d2 HbO
# Channel Index: 50
# Chromophore Index: 0
#
# Measurement: S01_D05d2 HbR
# Channel Index: 50
# Chromophore Index: 1
#
# Measurement: S01_D05d3 HbO
# Channel Index: 51
# Chromophore Index: 0
#
# Measurement: S01_D05d3 HbR
# Channel Index: 51
# Chromophore Index: 1
#
# Measurement: S01_D05d4 HbO
# Channel Index: 52
# Chromophore Index: 0
#
# Measurement: S01_D05d4 HbR
# Channel Index: 52
# Chromophore Index: 1
#
# Measurement: S01_D05d5 HbO
# Channel Index: 53
# Chromophore Index: 0
#
# Measurement: S01_D05d5 HbR
# Channel Index: 53
# Chromophore Index: 1
#
# Measurement: S01_D05d0 HbO
# Channel Index: 48
# Chromophore Index: 0
#
# Measurement: S01_D05d0 HbR
# Channel Index: 48
# Chromophore Index: 1
#
# Measurement: S01_D07d5 HbO
# Channel Index: 57
# Chromophore Index: 0
#
# Measurement: S01_D07d5 HbR
# Channel Index: 57
# Chromophore Index: 1
#
# Measurement: S01_D07d0 HbO
# Channel Index: 54
# Chromophore Index: 0
#
# Measurement: S01_D07d0 HbR
# Channel Index: 54
# Chromophore Index: 1
#
# Measurement: S01_D07d3 HbO
# Channel Index: 55
# Chromophore Index: 0
#
# Measurement: S01_D07d3 HbR
# Channel Index: 55
# Chromophore Index: 1
#
# Measurement: S01_D07d4 HbO
# Channel Index: 56
# Chromophore Index: 0
#
# Measurement: S01_D07d4 HbR
# Channel Index: 56
# Chromophore Index: 1
#
# Measurement: S01_D09d2 HbO
# Channel Index: 60
# Chromophore Index: 0
#
# Measurement: S01_D09d2 HbR
# Channel Index: 60
# Chromophore Index: 1
#
# Measurement: S01_D09d3 HbO
# Channel Index: 61
# Chromophore Index: 0
#
# Measurement: S01_D09d3 HbR
# Channel Index: 61
# Chromophore Index: 1
#
# Measurement: S01_D09d4 HbO
# Channel Index: 62
# Chromophore Index: 0
#
# Measurement: S01_D09d4 HbR
# Channel Index: 62
# Chromophore Index: 1
#
# Measurement: S01_D09d1 HbO
# Channel Index: 59
# Chromophore Index: 0
#
# Measurement: S01_D09d1 HbR
# Channel Index: 59
# Chromophore Index: 1
#
# Measurement: S01_D11d3 HbO
# Channel Index: 64
# Chromophore Index: 0
#
# Measurement: S01_D11d3 HbR
# Channel Index: 64
# Chromophore Index: 1
#
# Measurement: S01_D11d4 HbO
# Channel Index: 65
# Chromophore Index: 0
#
# Measurement: S01_D11d4 HbR
# Channel Index: 65
# Chromophore Index: 1
#
# Measurement: S01_D11d2 HbO
# Channel Index: 63
# Chromophore Index: 0
#
# Measurement: S01_D11d2 HbR
# Channel Index: 63
# Chromophore Index: 1
#
# Measurement: S01_D00d1 HbO
# Channel Index: 33
# Chromophore Index: 0
#
# Measurement: S01_D00d1 HbR
# Channel Index: 33
# Chromophore Index: 1
#
# Measurement: S01_D00d3 HbO
# Channel Index: 35
# Chromophore Index: 0
#
# Measurement: S01_D00d3 HbR
# Channel Index: 35
# Chromophore Index: 1
#
# Measurement: S01_D00d2 HbO
# Channel Index: 34
# Chromophore Index: 0
#
# Measurement: S01_D00d2 HbR
# Channel Index: 34
# Chromophore Index: 1
#
# Measurement: S01_D08d1 HbO
# Channel Index: 58
# Chromophore Index: 0
#
# Measurement: S01_D08d1 HbR
# Channel Index: 58
# Chromophore Index: 1
#
# Measurement: S03_D01d1 HbO
# Channel Index: 104
# Chromophore Index: 0
#
# Measurement: S03_D01d1 HbR
# Channel Index: 104
# Chromophore Index: 1
#
# Measurement: S03_D01d2 HbO
# Channel Index: 105
# Chromophore Index: 0
#
# Measurement: S03_D01d2 HbR
# Channel Index: 105
# Chromophore Index: 1
#
# Measurement: S03_D01d3 HbO
# Channel Index: 106
# Chromophore Index: 0
#
# Measurement: S03_D01d3 HbR
# Channel Index: 106
# Chromophore Index: 1
#
# Measurement: S03_D01d4 HbO
# Channel Index: 107
# Chromophore Index: 0
#
# Measurement: S03_D01d4 HbR
# Channel Index: 107
# Chromophore Index: 1
#
# Measurement: S03_D01d5 HbO
# Channel Index: 108
# Chromophore Index: 0
#
# Measurement: S03_D01d5 HbR
# Channel Index: 108
# Chromophore Index: 1
#
# Measurement: S03_D01d0 HbO
# Channel Index: 103
# Chromophore Index: 0
#
# Measurement: S03_D01d0 HbR
# Channel Index: 103
# Chromophore Index: 1
#
# Measurement: S03_D03d5 HbO
# Channel Index: 114
# Chromophore Index: 0
#
# Measurement: S03_D03d5 HbR
# Channel Index: 114
# Chromophore Index: 1
#
# Measurement: S03_D03d0 HbO
# Channel Index: 109
# Chromophore Index: 0
#
# Measurement: S03_D03d0 HbR
# Channel Index: 109
# Chromophore Index: 1
#
# Measurement: S03_D03d1 HbO
# Channel Index: 110
# Chromophore Index: 0
#
# Measurement: S03_D03d1 HbR
# Channel Index: 110
# Chromophore Index: 1
#
# Measurement: S03_D03d2 HbO
# Channel Index: 111
# Chromophore Index: 0
#
# Measurement: S03_D03d2 HbR
# Channel Index: 111
# Chromophore Index: 1
#
# Measurement: S03_D03d3 HbO
# Channel Index: 112
# Chromophore Index: 0
#
# Measurement: S03_D03d3 HbR
# Channel Index: 112
# Chromophore Index: 1
#
# Measurement: S03_D03d4 HbO
# Channel Index: 113
# Chromophore Index: 0
#
# Measurement: S03_D03d4 HbR
# Channel Index: 113
# Chromophore Index: 1
#
# Measurement: S03_D05d1 HbO
# Channel Index: 116
# Chromophore Index: 0
#
# Measurement: S03_D05d1 HbR
# Channel Index: 116
# Chromophore Index: 1
#
# Measurement: S03_D05d2 HbO
# Channel Index: 117
# Chromophore Index: 0
#
# Measurement: S03_D05d2 HbR
# Channel Index: 117
# Chromophore Index: 1
#
# Measurement: S03_D05d3 HbO
# Channel Index: 118
# Chromophore Index: 0
#
# Measurement: S03_D05d3 HbR
# Channel Index: 118
# Chromophore Index: 1
#
# Measurement: S03_D05d4 HbO
# Channel Index: 119
# Chromophore Index: 0
#
# Measurement: S03_D05d4 HbR
# Channel Index: 119
# Chromophore Index: 1
#
# Measurement: S03_D05d5 HbO
# Channel Index: 120
# Chromophore Index: 0
#
# Measurement: S03_D05d5 HbR
# Channel Index: 120
# Chromophore Index: 1
#
# Measurement: S03_D05d0 HbO
# Channel Index: 115
# Chromophore Index: 0
#
# Measurement: S03_D05d0 HbR
# Channel Index: 115
# Chromophore Index: 1
#
# Measurement: S03_D07d5 HbO
# Channel Index: 126
# Chromophore Index: 0
#
# Measurement: S03_D07d5 HbR
# Channel Index: 126
# Chromophore Index: 1
#
# Measurement: S03_D07d0 HbO
# Channel Index: 121
# Chromophore Index: 0
#
# Measurement: S03_D07d0 HbR
# Channel Index: 121
# Chromophore Index: 1
#
# Measurement: S03_D07d1 HbO
# Channel Index: 122
# Chromophore Index: 0
#
# Measurement: S03_D07d1 HbR
# Channel Index: 122
# Chromophore Index: 1
#
# Measurement: S03_D07d2 HbO
# Channel Index: 123
# Chromophore Index: 0
#
# Measurement: S03_D07d2 HbR
# Channel Index: 123
# Chromophore Index: 1
#
# Measurement: S03_D07d3 HbO
# Channel Index: 124
# Chromophore Index: 0
#
# Measurement: S03_D07d3 HbR
# Channel Index: 124
# Chromophore Index: 1
#
# Measurement: S03_D07d4 HbO
# Channel Index: 125
# Chromophore Index: 0
#
# Measurement: S03_D07d4 HbR
# Channel Index: 125
# Chromophore Index: 1
#
# Measurement: S03_D09d2 HbO
# Channel Index: 127
# Chromophore Index: 0
#
# Measurement: S03_D09d2 HbR
# Channel Index: 127
# Chromophore Index: 1
#
# Measurement: S03_D09d3 HbO
# Channel Index: 128
# Chromophore Index: 0
#
# Measurement: S03_D09d3 HbR
# Channel Index: 128
# Chromophore Index: 1
#
# Measurement: S03_D09d4 HbO
# Channel Index: 129
# Chromophore Index: 0
#
# Measurement: S03_D09d4 HbR
# Channel Index: 129
# Chromophore Index: 1
#
# Measurement: S03_D11d3 HbO
# Channel Index: 131
# Chromophore Index: 0
#
# Measurement: S03_D11d3 HbR
# Channel Index: 131
# Chromophore Index: 1
#
# Measurement: S03_D11d4 HbO
# Channel Index: 132
# Chromophore Index: 0
#
# Measurement: S03_D11d4 HbR
# Channel Index: 132
# Chromophore Index: 1
#
# Measurement: S03_D11d5 HbO
# Channel Index: 133
# Chromophore Index: 0
#
# Measurement: S03_D11d5 HbR
# Channel Index: 133
# Chromophore Index: 1
#
# Measurement: S03_D11d2 HbO
# Channel Index: 130
# Chromophore Index: 0
#
# Measurement: S03_D11d2 HbR
# Channel Index: 130
# Chromophore Index: 1
#
# Measurement: S03_D19d2 HbO
# Channel Index: 136
# Chromophore Index: 0
#
# Measurement: S03_D19d2 HbR
# Channel Index: 136
# Chromophore Index: 1
#
# Measurement: S03_D19d3 HbO
# Channel Index: 137
# Chromophore Index: 0
#
# Measurement: S03_D19d3 HbR
# Channel Index: 137
# Chromophore Index: 1
#
# Measurement: S03_D19d4 HbO
# Channel Index: 138
# Chromophore Index: 0
#
# Measurement: S03_D19d4 HbR
# Channel Index: 138
# Chromophore Index: 1
#
# Measurement: S03_D19d5 HbO
# Channel Index: 139
# Chromophore Index: 0
#
# Measurement: S03_D19d5 HbR
# Channel Index: 139
# Chromophore Index: 1
#
# Measurement: S03_D19d0 HbO
# Channel Index: 134
# Chromophore Index: 0
#
# Measurement: S03_D19d0 HbR
# Channel Index: 134
# Chromophore Index: 1
#
# Measurement: S03_D19d1 HbO
# Channel Index: 135
# Chromophore Index: 0
#
# Measurement: S03_D19d1 HbR
# Channel Index: 135
# Chromophore Index: 1
#
# Measurement: S05_D01d1 HbO
# Channel Index: 182
# Chromophore Index: 0
#
# Measurement: S05_D01d1 HbR
# Channel Index: 182
# Chromophore Index: 1
#
# Measurement: S05_D01d2 HbO
# Channel Index: 183
# Chromophore Index: 0
#
# Measurement: S05_D01d2 HbR
# Channel Index: 183
# Chromophore Index: 1
#
# Measurement: S05_D01d3 HbO
# Channel Index: 184
# Chromophore Index: 0
#
# Measurement: S05_D01d3 HbR
# Channel Index: 184
# Chromophore Index: 1
#
# Measurement: S05_D01d4 HbO
# Channel Index: 185
# Chromophore Index: 0
#
# Measurement: S05_D01d4 HbR
# Channel Index: 185
# Chromophore Index: 1
#
# Measurement: S05_D01d5 HbO
# Channel Index: 186
# Chromophore Index: 0
#
# Measurement: S05_D01d5 HbR
# Channel Index: 186
# Chromophore Index: 1
#
# Measurement: S05_D01d0 HbO
# Channel Index: 181
# Chromophore Index: 0
#
# Measurement: S05_D01d0 HbR
# Channel Index: 181
# Chromophore Index: 1
#
# Measurement: S05_D03d5 HbO
# Channel Index: 192
# Chromophore Index: 0
#
# Measurement: S05_D03d5 HbR
# Channel Index: 192
# Chromophore Index: 1
#
# Measurement: S05_D03d0 HbO
# Channel Index: 187
# Chromophore Index: 0
#
# Measurement: S05_D03d0 HbR
# Channel Index: 187
# Chromophore Index: 1
#
# Measurement: S05_D03d1 HbO
# Channel Index: 188
# Chromophore Index: 0
#
# Measurement: S05_D03d1 HbR
# Channel Index: 188
# Chromophore Index: 1
#
# Measurement: S05_D03d2 HbO
# Channel Index: 189
# Chromophore Index: 0
#
# Measurement: S05_D03d2 HbR
# Channel Index: 189
# Chromophore Index: 1
#
# Measurement: S05_D03d3 HbO
# Channel Index: 190
# Chromophore Index: 0
#
# Measurement: S05_D03d3 HbR
# Channel Index: 190
# Chromophore Index: 1
#
# Measurement: S05_D03d4 HbO
# Channel Index: 191
# Chromophore Index: 0
#
# Measurement: S05_D03d4 HbR
# Channel Index: 191
# Chromophore Index: 1
#
# Measurement: S05_D05d1 HbO
# Channel Index: 194
# Chromophore Index: 0
#
# Measurement: S05_D05d1 HbR
# Channel Index: 194
# Chromophore Index: 1
#
# Measurement: S05_D05d2 HbO
# Channel Index: 195
# Chromophore Index: 0
#
# Measurement: S05_D05d2 HbR
# Channel Index: 195
# Chromophore Index: 1
#
# Measurement: S05_D05d3 HbO
# Channel Index: 196
# Chromophore Index: 0
#
# Measurement: S05_D05d3 HbR
# Channel Index: 196
# Chromophore Index: 1
#
# Measurement: S05_D05d4 HbO
# Channel Index: 197
# Chromophore Index: 0
#
# Measurement: S05_D05d4 HbR
# Channel Index: 197
# Chromophore Index: 1
#
# Measurement: S05_D05d5 HbO
# Channel Index: 198
# Chromophore Index: 0
#
# Measurement: S05_D05d5 HbR
# Channel Index: 198
# Chromophore Index: 1
#
# Measurement: S05_D05d0 HbO
# Channel Index: 193
# Chromophore Index: 0
#
# Measurement: S05_D05d0 HbR
# Channel Index: 193
# Chromophore Index: 1
#
# Measurement: S05_D07d5 HbO
# Channel Index: 204
# Chromophore Index: 0
#
# Measurement: S05_D07d5 HbR
# Channel Index: 204
# Chromophore Index: 1
#
# Measurement: S05_D07d0 HbO
# Channel Index: 199
# Chromophore Index: 0
#
# Measurement: S05_D07d0 HbR
# Channel Index: 199
# Chromophore Index: 1
#
# Measurement: S05_D07d1 HbO
# Channel Index: 200
# Chromophore Index: 0
#
# Measurement: S05_D07d1 HbR
# Channel Index: 200
# Chromophore Index: 1
#
# Measurement: S05_D07d2 HbO
# Channel Index: 201
# Chromophore Index: 0
#
# Measurement: S05_D07d2 HbR
# Channel Index: 201
# Chromophore Index: 1
#
# Measurement: S05_D07d3 HbO
# Channel Index: 202
# Chromophore Index: 0
#
# Measurement: S05_D07d3 HbR
# Channel Index: 202
# Chromophore Index: 1
#
# Measurement: S05_D07d4 HbO
# Channel Index: 203
# Chromophore Index: 0
#
# Measurement: S05_D07d4 HbR
# Channel Index: 203
# Chromophore Index: 1
#
# Measurement: S05_D09d2 HbO
# Channel Index: 210
# Chromophore Index: 0
#
# Measurement: S05_D09d2 HbR
# Channel Index: 210
# Chromophore Index: 1
#
# Measurement: S05_D09d3 HbO
# Channel Index: 211
# Chromophore Index: 0
#
# Measurement: S05_D09d3 HbR
# Channel Index: 211
# Chromophore Index: 1
#
# Measurement: S05_D09d4 HbO
# Channel Index: 212
# Chromophore Index: 0
#
# Measurement: S05_D09d4 HbR
# Channel Index: 212
# Chromophore Index: 1
#
# Measurement: S05_D09d5 HbO
# Channel Index: 213
# Chromophore Index: 0
#
# Measurement: S05_D09d5 HbR
# Channel Index: 213
# Chromophore Index: 1
#
# Measurement: S05_D09d0 HbO
# Channel Index: 208
# Chromophore Index: 0
#
# Measurement: S05_D09d0 HbR
# Channel Index: 208
# Chromophore Index: 1
#
# Measurement: S05_D09d1 HbO
# Channel Index: 209
# Chromophore Index: 0
#
# Measurement: S05_D09d1 HbR
# Channel Index: 209
# Chromophore Index: 1
#
# Measurement: S05_D11d3 HbO
# Channel Index: 217
# Chromophore Index: 0
#
# Measurement: S05_D11d3 HbR
# Channel Index: 217
# Chromophore Index: 1
#
# Measurement: S05_D11d4 HbO
# Channel Index: 218
# Chromophore Index: 0
#
# Measurement: S05_D11d4 HbR
# Channel Index: 218
# Chromophore Index: 1
#
# Measurement: S05_D11d5 HbO
# Channel Index: 219
# Chromophore Index: 0
#
# Measurement: S05_D11d5 HbR
# Channel Index: 219
# Chromophore Index: 1
#
# Measurement: S05_D11d0 HbO
# Channel Index: 214
# Chromophore Index: 0
#
# Measurement: S05_D11d0 HbR
# Channel Index: 214
# Chromophore Index: 1
#
# Measurement: S05_D11d1 HbO
# Channel Index: 215
# Chromophore Index: 0
#
# Measurement: S05_D11d1 HbR
# Channel Index: 215
# Chromophore Index: 1
#
# Measurement: S05_D11d2 HbO
# Channel Index: 216
# Chromophore Index: 0
#
# Measurement: S05_D11d2 HbR
# Channel Index: 216
# Chromophore Index: 1
#
# Measurement: S05_D19d2 HbO
# Channel Index: 221
# Chromophore Index: 0
#
# Measurement: S05_D19d2 HbR
# Channel Index: 221
# Chromophore Index: 1
#
# Measurement: S05_D19d1 HbO
# Channel Index: 220
# Chromophore Index: 0
#
# Measurement: S05_D19d1 HbR
# Channel Index: 220
# Chromophore Index: 1
#
# Measurement: S05_D08d0 HbO
# Channel Index: 205
# Chromophore Index: 0
#
# Measurement: S05_D08d0 HbR
# Channel Index: 205
# Chromophore Index: 1
#
# Measurement: S05_D08d2 HbO
# Channel Index: 207
# Chromophore Index: 0
#
# Measurement: S05_D08d2 HbR
# Channel Index: 207
# Chromophore Index: 1
#
# Measurement: S05_D08d1 HbO
# Channel Index: 206
# Chromophore Index: 0
#
# Measurement: S05_D08d1 HbR
# Channel Index: 206
# Chromophore Index: 1
#
# Measurement: S07_D01d2 HbO
# Channel Index: 269
# Chromophore Index: 0
#
# Measurement: S07_D01d2 HbR
# Channel Index: 269
# Chromophore Index: 1
#
# Measurement: S07_D01d3 HbO
# Channel Index: 270
# Chromophore Index: 0
#
# Measurement: S07_D01d3 HbR
# Channel Index: 270
# Chromophore Index: 1
#
# Measurement: S07_D01d4 HbO
# Channel Index: 271
# Chromophore Index: 0
#
# Measurement: S07_D01d4 HbR
# Channel Index: 271
# Chromophore Index: 1
#
# Measurement: S07_D01d5 HbO
# Channel Index: 272
# Chromophore Index: 0
#
# Measurement: S07_D01d5 HbR
# Channel Index: 272
# Chromophore Index: 1
#
# Measurement: S07_D03d5 HbO
# Channel Index: 278
# Chromophore Index: 0
#
# Measurement: S07_D03d5 HbR
# Channel Index: 278
# Chromophore Index: 1
#
# Measurement: S07_D03d0 HbO
# Channel Index: 273
# Chromophore Index: 0
#
# Measurement: S07_D03d0 HbR
# Channel Index: 273
# Chromophore Index: 1
#
# Measurement: S07_D03d1 HbO
# Channel Index: 274
# Chromophore Index: 0
#
# Measurement: S07_D03d1 HbR
# Channel Index: 274
# Chromophore Index: 1
#
# Measurement: S07_D03d2 HbO
# Channel Index: 275
# Chromophore Index: 0
#
# Measurement: S07_D03d2 HbR
# Channel Index: 275
# Chromophore Index: 1
#
# Measurement: S07_D03d3 HbO
# Channel Index: 276
# Chromophore Index: 0
#
# Measurement: S07_D03d3 HbR
# Channel Index: 276
# Chromophore Index: 1
#
# Measurement: S07_D03d4 HbO
# Channel Index: 277
# Chromophore Index: 0
#
# Measurement: S07_D03d4 HbR
# Channel Index: 277
# Chromophore Index: 1
#
# Measurement: S07_D05d1 HbO
# Channel Index: 280
# Chromophore Index: 0
#
# Measurement: S07_D05d1 HbR
# Channel Index: 280
# Chromophore Index: 1
#
# Measurement: S07_D05d2 HbO
# Channel Index: 281
# Chromophore Index: 0
#
# Measurement: S07_D05d2 HbR
# Channel Index: 281
# Chromophore Index: 1
#
# Measurement: S07_D05d3 HbO
# Channel Index: 282
# Chromophore Index: 0
#
# Measurement: S07_D05d3 HbR
# Channel Index: 282
# Chromophore Index: 1
#
# Measurement: S07_D05d4 HbO
# Channel Index: 283
# Chromophore Index: 0
#
# Measurement: S07_D05d4 HbR
# Channel Index: 283
# Chromophore Index: 1
#
# Measurement: S07_D05d5 HbO
# Channel Index: 284
# Chromophore Index: 0
#
# Measurement: S07_D05d5 HbR
# Channel Index: 284
# Chromophore Index: 1
#
# Measurement: S07_D05d0 HbO
# Channel Index: 279
# Chromophore Index: 0
#
# Measurement: S07_D05d0 HbR
# Channel Index: 279
# Chromophore Index: 1
#
# Measurement: S07_D07d5 HbO
# Channel Index: 290
# Chromophore Index: 0
#
# Measurement: S07_D07d5 HbR
# Channel Index: 290
# Chromophore Index: 1
#
# Measurement: S07_D07d0 HbO
# Channel Index: 285
# Chromophore Index: 0
#
# Measurement: S07_D07d0 HbR
# Channel Index: 285
# Chromophore Index: 1
#
# Measurement: S07_D07d1 HbO
# Channel Index: 286
# Chromophore Index: 0
#
# Measurement: S07_D07d1 HbR
# Channel Index: 286
# Chromophore Index: 1
#
# Measurement: S07_D07d2 HbO
# Channel Index: 287
# Chromophore Index: 0
#
# Measurement: S07_D07d2 HbR
# Channel Index: 287
# Chromophore Index: 1
#
# Measurement: S07_D07d3 HbO
# Channel Index: 288
# Chromophore Index: 0
#
# Measurement: S07_D07d3 HbR
# Channel Index: 288
# Chromophore Index: 1
#
# Measurement: S07_D07d4 HbO
# Channel Index: 289
# Chromophore Index: 0
#
# Measurement: S07_D07d4 HbR
# Channel Index: 289
# Chromophore Index: 1
#
# Measurement: S07_D09d2 HbO
# Channel Index: 291
# Chromophore Index: 0
#
# Measurement: S07_D09d2 HbR
# Channel Index: 291
# Chromophore Index: 1
#
# Measurement: S07_D09d3 HbO
# Channel Index: 292
# Chromophore Index: 0
#
# Measurement: S07_D09d3 HbR
# Channel Index: 292
# Chromophore Index: 1
#
# Measurement: S07_D09d4 HbO
# Channel Index: 293
# Chromophore Index: 0
#
# Measurement: S07_D09d4 HbR
# Channel Index: 293
# Chromophore Index: 1
#
# Measurement: S07_D09d5 HbO
# Channel Index: 294
# Chromophore Index: 0
#
# Measurement: S07_D09d5 HbR
# Channel Index: 294
# Chromophore Index: 1
#
# Measurement: S07_D11d3 HbO
# Channel Index: 298
# Chromophore Index: 0
#
# Measurement: S07_D11d3 HbR
# Channel Index: 298
# Chromophore Index: 1
#
# Measurement: S07_D11d4 HbO
# Channel Index: 299
# Chromophore Index: 0
#
# Measurement: S07_D11d4 HbR
# Channel Index: 299
# Chromophore Index: 1
#
# Measurement: S07_D11d5 HbO
# Channel Index: 300
# Chromophore Index: 0
#
# Measurement: S07_D11d5 HbR
# Channel Index: 300
# Chromophore Index: 1
#
# Measurement: S07_D11d0 HbO
# Channel Index: 295
# Chromophore Index: 0
#
# Measurement: S07_D11d0 HbR
# Channel Index: 295
# Chromophore Index: 1
#
# Measurement: S07_D11d1 HbO
# Channel Index: 296
# Chromophore Index: 0
#
# Measurement: S07_D11d1 HbR
# Channel Index: 296
# Chromophore Index: 1
#
# Measurement: S07_D11d2 HbO
# Channel Index: 297
# Chromophore Index: 0
#
# Measurement: S07_D11d2 HbR
# Channel Index: 297
# Chromophore Index: 1
#
# Measurement: S07_D15d0 HbO
# Channel Index: 301
# Chromophore Index: 0
#
# Measurement: S07_D15d0 HbR
# Channel Index: 301
# Chromophore Index: 1
#
# Measurement: S07_D17d0 HbO
# Channel Index: 302
# Chromophore Index: 0
#
# Measurement: S07_D17d0 HbR
# Channel Index: 302
# Chromophore Index: 1
#
# Measurement: S07_D17d1 HbO
# Channel Index: 303
# Chromophore Index: 0
#
# Measurement: S07_D17d1 HbR
# Channel Index: 303
# Chromophore Index: 1
#
# Measurement: S07_D17d2 HbO
# Channel Index: 304
# Chromophore Index: 0
#
# Measurement: S07_D17d2 HbR
# Channel Index: 304
# Chromophore Index: 1
#
# Measurement: S07_D17d3 HbO
# Channel Index: 305
# Chromophore Index: 0
#
# Measurement: S07_D17d3 HbR
# Channel Index: 305
# Chromophore Index: 1
#
# Measurement: S07_D17d4 HbO
# Channel Index: 306
# Chromophore Index: 0
#
# Measurement: S07_D17d4 HbR
# Channel Index: 306
# Chromophore Index: 1
#
# Measurement: S07_D17d5 HbO
# Channel Index: 307
# Chromophore Index: 0
#
# Measurement: S07_D17d5 HbR
# Channel Index: 307
# Chromophore Index: 1
#
# Measurement: S07_D19d2 HbO
# Channel Index: 310
# Chromophore Index: 0
#
# Measurement: S07_D19d2 HbR
# Channel Index: 310
# Chromophore Index: 1
#
# Measurement: S07_D19d3 HbO
# Channel Index: 311
# Chromophore Index: 0
#
# Measurement: S07_D19d3 HbR
# Channel Index: 311
# Chromophore Index: 1
#
# Measurement: S07_D19d4 HbO
# Channel Index: 312
# Chromophore Index: 0
#
# Measurement: S07_D19d4 HbR
# Channel Index: 312
# Chromophore Index: 1
#
# Measurement: S07_D19d5 HbO
# Channel Index: 313
# Chromophore Index: 0
#
# Measurement: S07_D19d5 HbR
# Channel Index: 313
# Chromophore Index: 1
#
# Measurement: S07_D19d0 HbO
# Channel Index: 308
# Chromophore Index: 0
#
# Measurement: S07_D19d0 HbR
# Channel Index: 308
# Chromophore Index: 1
#
# Measurement: S07_D19d1 HbO
# Channel Index: 309
# Chromophore Index: 0
#
# Measurement: S07_D19d1 HbR
# Channel Index: 309
# Chromophore Index: 1
#
# Measurement: S07_D27d3 HbO
# Channel Index: 315
# Chromophore Index: 0
#
# Measurement: S07_D27d3 HbR
# Channel Index: 315
# Chromophore Index: 1
#
# Measurement: S07_D27d2 HbO
# Channel Index: 314
# Chromophore Index: 0
#
# Measurement: S07_D27d2 HbR
# Channel Index: 314
# Chromophore Index: 1
#
# Measurement: S09_D01d3 HbO
# Channel Index: 363
# Chromophore Index: 0
#
# Measurement: S09_D01d3 HbR
# Channel Index: 363
# Chromophore Index: 1
#
# Measurement: S09_D01d4 HbO
# Channel Index: 364
# Chromophore Index: 0
#
# Measurement: S09_D01d4 HbR
# Channel Index: 364
# Chromophore Index: 1
#
# Measurement: S09_D01d5 HbO
# Channel Index: 365
# Chromophore Index: 0
#
# Measurement: S09_D01d5 HbR
# Channel Index: 365
# Chromophore Index: 1
#
# Measurement: S09_D01d0 HbO
# Channel Index: 362
# Chromophore Index: 0
#
# Measurement: S09_D01d0 HbR
# Channel Index: 362
# Chromophore Index: 1
#
# Measurement: S09_D03d2 HbO
# Channel Index: 366
# Chromophore Index: 0
#
# Measurement: S09_D03d2 HbR
# Channel Index: 366
# Chromophore Index: 1
#
# Measurement: S09_D03d3 HbO
# Channel Index: 367
# Chromophore Index: 0
#
# Measurement: S09_D03d3 HbR
# Channel Index: 367
# Chromophore Index: 1
#
# Measurement: S09_D03d4 HbO
# Channel Index: 368
# Chromophore Index: 0
#
# Measurement: S09_D03d4 HbR
# Channel Index: 368
# Chromophore Index: 1
#
# Measurement: S09_D05d1 HbO
# Channel Index: 373
# Chromophore Index: 0
#
# Measurement: S09_D05d1 HbR
# Channel Index: 373
# Chromophore Index: 1
#
# Measurement: S09_D05d2 HbO
# Channel Index: 374
# Chromophore Index: 0
#
# Measurement: S09_D05d2 HbR
# Channel Index: 374
# Chromophore Index: 1
#
# Measurement: S09_D05d3 HbO
# Channel Index: 375
# Chromophore Index: 0
#
# Measurement: S09_D05d3 HbR
# Channel Index: 375
# Chromophore Index: 1
#
# Measurement: S09_D05d4 HbO
# Channel Index: 376
# Chromophore Index: 0
#
# Measurement: S09_D05d4 HbR
# Channel Index: 376
# Chromophore Index: 1
#
# Measurement: S09_D05d5 HbO
# Channel Index: 377
# Chromophore Index: 0
#
# Measurement: S09_D05d5 HbR
# Channel Index: 377
# Chromophore Index: 1
#
# Measurement: S09_D05d0 HbO
# Channel Index: 372
# Chromophore Index: 0
#
# Measurement: S09_D05d0 HbR
# Channel Index: 372
# Chromophore Index: 1
#
# Measurement: S09_D07d5 HbO
# Channel Index: 381
# Chromophore Index: 0
#
# Measurement: S09_D07d5 HbR
# Channel Index: 381
# Chromophore Index: 1
#
# Measurement: S09_D07d2 HbO
# Channel Index: 378
# Chromophore Index: 0
#
# Measurement: S09_D07d2 HbR
# Channel Index: 378
# Chromophore Index: 1
#
# Measurement: S09_D07d3 HbO
# Channel Index: 379
# Chromophore Index: 0
#
# Measurement: S09_D07d3 HbR
# Channel Index: 379
# Chromophore Index: 1
#
# Measurement: S09_D07d4 HbO
# Channel Index: 380
# Chromophore Index: 0
#
# Measurement: S09_D07d4 HbR
# Channel Index: 380
# Chromophore Index: 1
#
# Measurement: S09_D09d2 HbO
# Channel Index: 390
# Chromophore Index: 0
#
# Measurement: S09_D09d2 HbR
# Channel Index: 390
# Chromophore Index: 1
#
# Measurement: S09_D09d3 HbO
# Channel Index: 391
# Chromophore Index: 0
#
# Measurement: S09_D09d3 HbR
# Channel Index: 391
# Chromophore Index: 1
#
# Measurement: S09_D09d4 HbO
# Channel Index: 392
# Chromophore Index: 0
#
# Measurement: S09_D09d4 HbR
# Channel Index: 392
# Chromophore Index: 1
#
# Measurement: S09_D09d5 HbO
# Channel Index: 393
# Chromophore Index: 0
#
# Measurement: S09_D09d5 HbR
# Channel Index: 393
# Chromophore Index: 1
#
# Measurement: S09_D09d0 HbO
# Channel Index: 388
# Chromophore Index: 0
#
# Measurement: S09_D09d0 HbR
# Channel Index: 388
# Chromophore Index: 1
#
# Measurement: S09_D09d1 HbO
# Channel Index: 389
# Chromophore Index: 0
#
# Measurement: S09_D09d1 HbR
# Channel Index: 389
# Chromophore Index: 1
#
# Measurement: S09_D11d3 HbO
# Channel Index: 400
# Chromophore Index: 0
#
# Measurement: S09_D11d3 HbR
# Channel Index: 400
# Chromophore Index: 1
#
# Measurement: S09_D11d4 HbO
# Channel Index: 401
# Chromophore Index: 0
#
# Measurement: S09_D11d4 HbR
# Channel Index: 401
# Chromophore Index: 1
#
# Measurement: S09_D11d5 HbO
# Channel Index: 402
# Chromophore Index: 0
#
# Measurement: S09_D11d5 HbR
# Channel Index: 402
# Chromophore Index: 1
#
# Measurement: S09_D11d0 HbO
# Channel Index: 397
# Chromophore Index: 0
#
# Measurement: S09_D11d0 HbR
# Channel Index: 397
# Chromophore Index: 1
#
# Measurement: S09_D11d1 HbO
# Channel Index: 398
# Chromophore Index: 0
#
# Measurement: S09_D11d1 HbR
# Channel Index: 398
# Chromophore Index: 1
#
# Measurement: S09_D11d2 HbO
# Channel Index: 399
# Chromophore Index: 0
#
# Measurement: S09_D11d2 HbR
# Channel Index: 399
# Chromophore Index: 1
#
# Measurement: S09_D13d1 HbO
# Channel Index: 404
# Chromophore Index: 0
#
# Measurement: S09_D13d1 HbR
# Channel Index: 404
# Chromophore Index: 1
#
# Measurement: S09_D13d2 HbO
# Channel Index: 405
# Chromophore Index: 0
#
# Measurement: S09_D13d2 HbR
# Channel Index: 405
# Chromophore Index: 1
#
# Measurement: S09_D13d0 HbO
# Channel Index: 403
# Chromophore Index: 0
#
# Measurement: S09_D13d0 HbR
# Channel Index: 403
# Chromophore Index: 1
#
# Measurement: S09_D00d3 HbO
# Channel Index: 361
# Chromophore Index: 0
#
# Measurement: S09_D00d3 HbR
# Channel Index: 361
# Chromophore Index: 1
#
# Measurement: S09_D04d4 HbO
# Channel Index: 371
# Chromophore Index: 0
#
# Measurement: S09_D04d4 HbR
# Channel Index: 371
# Chromophore Index: 1
#
# Measurement: S09_D04d3 HbO
# Channel Index: 370
# Chromophore Index: 0
#
# Measurement: S09_D04d3 HbR
# Channel Index: 370
# Chromophore Index: 1
#
# Measurement: S09_D04d2 HbO
# Channel Index: 369
# Chromophore Index: 0
#
# Measurement: S09_D04d2 HbR
# Channel Index: 369
# Chromophore Index: 1
#
# Measurement: S09_D08d0 HbO
# Channel Index: 382
# Chromophore Index: 0
#
# Measurement: S09_D08d0 HbR
# Channel Index: 382
# Chromophore Index: 1
#
# Measurement: S09_D08d5 HbO
# Channel Index: 387
# Chromophore Index: 0
#
# Measurement: S09_D08d5 HbR
# Channel Index: 387
# Chromophore Index: 1
#
# Measurement: S09_D08d4 HbO
# Channel Index: 386
# Chromophore Index: 0
#
# Measurement: S09_D08d4 HbR
# Channel Index: 386
# Chromophore Index: 1
#
# Measurement: S09_D08d3 HbO
# Channel Index: 385
# Chromophore Index: 0
#
# Measurement: S09_D08d3 HbR
# Channel Index: 385
# Chromophore Index: 1
#
# Measurement: S09_D08d2 HbO
# Channel Index: 384
# Chromophore Index: 0
#
# Measurement: S09_D08d2 HbR
# Channel Index: 384
# Chromophore Index: 1
#
# Measurement: S09_D08d1 HbO
# Channel Index: 383
# Chromophore Index: 0
#
# Measurement: S09_D08d1 HbR
# Channel Index: 383
# Chromophore Index: 1
#
# Measurement: S09_D10d5 HbO
# Channel Index: 396
# Chromophore Index: 0
#
# Measurement: S09_D10d5 HbR
# Channel Index: 396
# Chromophore Index: 1
#
# Measurement: S09_D10d1 HbO
# Channel Index: 395
# Chromophore Index: 0
#
# Measurement: S09_D10d1 HbR
# Channel Index: 395
# Chromophore Index: 1
#
# Measurement: S09_D10d0 HbO
# Channel Index: 394
# Chromophore Index: 0
#
# Measurement: S09_D10d0 HbR
# Channel Index: 394
# Chromophore Index: 1
#
# Measurement: S11_D01d3 HbO
# Channel Index: 455
# Chromophore Index: 0
#
# Measurement: S11_D01d3 HbR
# Channel Index: 455
# Chromophore Index: 1
#
# Measurement: S11_D01d4 HbO
# Channel Index: 456
# Chromophore Index: 0
#
# Measurement: S11_D01d4 HbR
# Channel Index: 456
# Chromophore Index: 1
#
# Measurement: S11_D01d5 HbO
# Channel Index: 457
# Chromophore Index: 0
#
# Measurement: S11_D01d5 HbR
# Channel Index: 457
# Chromophore Index: 1
#
# Measurement: S11_D03d1 HbO
# Channel Index: 458
# Chromophore Index: 0
#
# Measurement: S11_D03d1 HbR
# Channel Index: 458
# Chromophore Index: 1
#
# Measurement: S11_D03d2 HbO
# Channel Index: 459
# Chromophore Index: 0
#
# Measurement: S11_D03d2 HbR
# Channel Index: 459
# Chromophore Index: 1
#
# Measurement: S11_D03d3 HbO
# Channel Index: 460
# Chromophore Index: 0
#
# Measurement: S11_D03d3 HbR
# Channel Index: 460
# Chromophore Index: 1
#
# Measurement: S11_D03d4 HbO
# Channel Index: 461
# Chromophore Index: 0
#
# Measurement: S11_D03d4 HbR
# Channel Index: 461
# Chromophore Index: 1
#
# Measurement: S11_D05d1 HbO
# Channel Index: 463
# Chromophore Index: 0
#
# Measurement: S11_D05d1 HbR
# Channel Index: 463
# Chromophore Index: 1
#
# Measurement: S11_D05d2 HbO
# Channel Index: 464
# Chromophore Index: 0
#
# Measurement: S11_D05d2 HbR
# Channel Index: 464
# Chromophore Index: 1
#
# Measurement: S11_D05d3 HbO
# Channel Index: 465
# Chromophore Index: 0
#
# Measurement: S11_D05d3 HbR
# Channel Index: 465
# Chromophore Index: 1
#
# Measurement: S11_D05d4 HbO
# Channel Index: 466
# Chromophore Index: 0
#
# Measurement: S11_D05d4 HbR
# Channel Index: 466
# Chromophore Index: 1
#
# Measurement: S11_D05d5 HbO
# Channel Index: 467
# Chromophore Index: 0
#
# Measurement: S11_D05d5 HbR
# Channel Index: 467
# Chromophore Index: 1
#
# Measurement: S11_D05d0 HbO
# Channel Index: 462
# Chromophore Index: 0
#
# Measurement: S11_D05d0 HbR
# Channel Index: 462
# Chromophore Index: 1
#
# Measurement: S11_D07d5 HbO
# Channel Index: 473
# Chromophore Index: 0
#
# Measurement: S11_D07d5 HbR
# Channel Index: 473
# Chromophore Index: 1
#
# Measurement: S11_D07d0 HbO
# Channel Index: 468
# Chromophore Index: 0
#
# Measurement: S11_D07d0 HbR
# Channel Index: 468
# Chromophore Index: 1
#
# Measurement: S11_D07d1 HbO
# Channel Index: 469
# Chromophore Index: 0
#
# Measurement: S11_D07d1 HbR
# Channel Index: 469
# Chromophore Index: 1
#
# Measurement: S11_D07d2 HbO
# Channel Index: 470
# Chromophore Index: 0
#
# Measurement: S11_D07d2 HbR
# Channel Index: 470
# Chromophore Index: 1
#
# Measurement: S11_D07d3 HbO
# Channel Index: 471
# Chromophore Index: 0
#
# Measurement: S11_D07d3 HbR
# Channel Index: 471
# Chromophore Index: 1
#
# Measurement: S11_D07d4 HbO
# Channel Index: 472
# Chromophore Index: 0
#
# Measurement: S11_D07d4 HbR
# Channel Index: 472
# Chromophore Index: 1
#
# Measurement: S11_D09d2 HbO
# Channel Index: 479
# Chromophore Index: 0
#
# Measurement: S11_D09d2 HbR
# Channel Index: 479
# Chromophore Index: 1
#
# Measurement: S11_D09d3 HbO
# Channel Index: 480
# Chromophore Index: 0
#
# Measurement: S11_D09d3 HbR
# Channel Index: 480
# Chromophore Index: 1
#
# Measurement: S11_D09d4 HbO
# Channel Index: 481
# Chromophore Index: 0
#
# Measurement: S11_D09d4 HbR
# Channel Index: 481
# Chromophore Index: 1
#
# Measurement: S11_D09d5 HbO
# Channel Index: 482
# Chromophore Index: 0
#
# Measurement: S11_D09d5 HbR
# Channel Index: 482
# Chromophore Index: 1
#
# Measurement: S11_D09d0 HbO
# Channel Index: 477
# Chromophore Index: 0
#
# Measurement: S11_D09d0 HbR
# Channel Index: 477
# Chromophore Index: 1
#
# Measurement: S11_D09d1 HbO
# Channel Index: 478
# Chromophore Index: 0
#
# Measurement: S11_D09d1 HbR
# Channel Index: 478
# Chromophore Index: 1
#
# Measurement: S11_D11d3 HbO
# Channel Index: 486
# Chromophore Index: 0
#
# Measurement: S11_D11d3 HbR
# Channel Index: 486
# Chromophore Index: 1
#
# Measurement: S11_D11d4 HbO
# Channel Index: 487
# Chromophore Index: 0
#
# Measurement: S11_D11d4 HbR
# Channel Index: 487
# Chromophore Index: 1
#
# Measurement: S11_D11d5 HbO
# Channel Index: 488
# Chromophore Index: 0
#
# Measurement: S11_D11d5 HbR
# Channel Index: 488
# Chromophore Index: 1
#
# Measurement: S11_D11d0 HbO
# Channel Index: 483
# Chromophore Index: 0
#
# Measurement: S11_D11d0 HbR
# Channel Index: 483
# Chromophore Index: 1
#
# Measurement: S11_D11d1 HbO
# Channel Index: 484
# Chromophore Index: 0
#
# Measurement: S11_D11d1 HbR
# Channel Index: 484
# Chromophore Index: 1
#
# Measurement: S11_D11d2 HbO
# Channel Index: 485
# Chromophore Index: 0
#
# Measurement: S11_D11d2 HbR
# Channel Index: 485
# Chromophore Index: 1
#
# Measurement: S11_D13d1 HbO
# Channel Index: 490
# Chromophore Index: 0
#
# Measurement: S11_D13d1 HbR
# Channel Index: 490
# Chromophore Index: 1
#
# Measurement: S11_D13d2 HbO
# Channel Index: 491
# Chromophore Index: 0
#
# Measurement: S11_D13d2 HbR
# Channel Index: 491
# Chromophore Index: 1
#
# Measurement: S11_D13d3 HbO
# Channel Index: 492
# Chromophore Index: 0
#
# Measurement: S11_D13d3 HbR
# Channel Index: 492
# Chromophore Index: 1
#
# Measurement: S11_D13d4 HbO
# Channel Index: 493
# Chromophore Index: 0
#
# Measurement: S11_D13d4 HbR
# Channel Index: 493
# Chromophore Index: 1
#
# Measurement: S11_D13d5 HbO
# Channel Index: 494
# Chromophore Index: 0
#
# Measurement: S11_D13d5 HbR
# Channel Index: 494
# Chromophore Index: 1
#
# Measurement: S11_D13d0 HbO
# Channel Index: 489
# Chromophore Index: 0
#
# Measurement: S11_D13d0 HbR
# Channel Index: 489
# Chromophore Index: 1
#
# Measurement: S11_D15d0 HbO
# Channel Index: 495
# Chromophore Index: 0
#
# Measurement: S11_D15d0 HbR
# Channel Index: 495
# Chromophore Index: 1
#
# Measurement: S11_D15d1 HbO
# Channel Index: 496
# Chromophore Index: 0
#
# Measurement: S11_D15d1 HbR
# Channel Index: 496
# Chromophore Index: 1
#
# Measurement: S11_D15d5 HbO
# Channel Index: 497
# Chromophore Index: 0
#
# Measurement: S11_D15d5 HbR
# Channel Index: 497
# Chromophore Index: 1
#
# Measurement: S11_D17d0 HbO
# Channel Index: 498
# Chromophore Index: 0
#
# Measurement: S11_D17d0 HbR
# Channel Index: 498
# Chromophore Index: 1
#
# Measurement: S11_D17d1 HbO
# Channel Index: 499
# Chromophore Index: 0
#
# Measurement: S11_D17d1 HbR
# Channel Index: 499
# Chromophore Index: 1
#
# Measurement: S11_D17d4 HbO
# Channel Index: 500
# Chromophore Index: 0
#
# Measurement: S11_D17d4 HbR
# Channel Index: 500
# Chromophore Index: 1
#
# Measurement: S11_D17d5 HbO
# Channel Index: 501
# Chromophore Index: 0
#
# Measurement: S11_D17d5 HbR
# Channel Index: 501
# Chromophore Index: 1
#
# Measurement: S11_D19d2 HbO
# Channel Index: 503
# Chromophore Index: 0
#
# Measurement: S11_D19d2 HbR
# Channel Index: 503
# Chromophore Index: 1
#
# Measurement: S11_D19d1 HbO
# Channel Index: 502
# Chromophore Index: 0
#
# Measurement: S11_D19d1 HbR
# Channel Index: 502
# Chromophore Index: 1
#
# Measurement: S11_D08d3 HbO
# Channel Index: 476
# Chromophore Index: 0
#
# Measurement: S11_D08d3 HbR
# Channel Index: 476
# Chromophore Index: 1
#
# Measurement: S11_D08d2 HbO
# Channel Index: 475
# Chromophore Index: 0
#
# Measurement: S11_D08d2 HbR
# Channel Index: 475
# Chromophore Index: 1
#
# Measurement: S11_D08d1 HbO
# Channel Index: 474
# Chromophore Index: 0
#
# Measurement: S11_D08d1 HbR
# Channel Index: 474
# Chromophore Index: 1
#
# Measurement: S13_D09d4 HbO
# Channel Index: 546
# Chromophore Index: 0
#
# Measurement: S13_D09d4 HbR
# Channel Index: 546
# Chromophore Index: 1
#
# Measurement: S13_D09d5 HbO
# Channel Index: 547
# Chromophore Index: 0
#
# Measurement: S13_D09d5 HbR
# Channel Index: 547
# Chromophore Index: 1
#
# Measurement: S13_D09d0 HbO
# Channel Index: 545
# Chromophore Index: 0
#
# Measurement: S13_D09d0 HbR
# Channel Index: 545
# Chromophore Index: 1
#
# Measurement: S13_D11d3 HbO
# Channel Index: 551
# Chromophore Index: 0
#
# Measurement: S13_D11d3 HbR
# Channel Index: 551
# Chromophore Index: 1
#
# Measurement: S13_D11d4 HbO
# Channel Index: 552
# Chromophore Index: 0
#
# Measurement: S13_D11d4 HbR
# Channel Index: 552
# Chromophore Index: 1
#
# Measurement: S13_D11d5 HbO
# Channel Index: 553
# Chromophore Index: 0
#
# Measurement: S13_D11d5 HbR
# Channel Index: 553
# Chromophore Index: 1
#
# Measurement: S13_D11d0 HbO
# Channel Index: 548
# Chromophore Index: 0
#
# Measurement: S13_D11d0 HbR
# Channel Index: 548
# Chromophore Index: 1
#
# Measurement: S13_D11d1 HbO
# Channel Index: 549
# Chromophore Index: 0
#
# Measurement: S13_D11d1 HbR
# Channel Index: 549
# Chromophore Index: 1
#
# Measurement: S13_D11d2 HbO
# Channel Index: 550
# Chromophore Index: 0
#
# Measurement: S13_D11d2 HbR
# Channel Index: 550
# Chromophore Index: 1
#
# Measurement: S13_D13d1 HbO
# Channel Index: 561
# Chromophore Index: 0
#
# Measurement: S13_D13d1 HbR
# Channel Index: 561
# Chromophore Index: 1
#
# Measurement: S13_D13d2 HbO
# Channel Index: 562
# Chromophore Index: 0
#
# Measurement: S13_D13d2 HbR
# Channel Index: 562
# Chromophore Index: 1
#
# Measurement: S13_D13d3 HbO
# Channel Index: 563
# Chromophore Index: 0
#
# Measurement: S13_D13d3 HbR
# Channel Index: 563
# Chromophore Index: 1
#
# Measurement: S13_D13d4 HbO
# Channel Index: 564
# Chromophore Index: 0
#
# Measurement: S13_D13d4 HbR
# Channel Index: 564
# Chromophore Index: 1
#
# Measurement: S13_D13d5 HbO
# Channel Index: 565
# Chromophore Index: 0
#
# Measurement: S13_D13d5 HbR
# Channel Index: 565
# Chromophore Index: 1
#
# Measurement: S13_D13d0 HbO
# Channel Index: 560
# Chromophore Index: 0
#
# Measurement: S13_D13d0 HbR
# Channel Index: 560
# Chromophore Index: 1
#
# Measurement: S13_D15d0 HbO
# Channel Index: 566
# Chromophore Index: 0
#
# Measurement: S13_D15d0 HbR
# Channel Index: 566
# Chromophore Index: 1
#
# Measurement: S13_D15d1 HbO
# Channel Index: 567
# Chromophore Index: 0
#
# Measurement: S13_D15d1 HbR
# Channel Index: 567
# Chromophore Index: 1
#
# Measurement: S13_D15d2 HbO
# Channel Index: 568
# Chromophore Index: 0
#
# Measurement: S13_D15d2 HbR
# Channel Index: 568
# Chromophore Index: 1
#
# Measurement: S13_D15d3 HbO
# Channel Index: 569
# Chromophore Index: 0
#
# Measurement: S13_D15d3 HbR
# Channel Index: 569
# Chromophore Index: 1
#
# Measurement: S13_D15d4 HbO
# Channel Index: 570
# Chromophore Index: 0
#
# Measurement: S13_D15d4 HbR
# Channel Index: 570
# Chromophore Index: 1
#
# Measurement: S13_D15d5 HbO
# Channel Index: 571
# Chromophore Index: 0
#
# Measurement: S13_D15d5 HbR
# Channel Index: 571
# Chromophore Index: 1
#
# Measurement: S13_D21d1 HbO
# Channel Index: 576
# Chromophore Index: 0
#
# Measurement: S13_D21d1 HbR
# Channel Index: 576
# Chromophore Index: 1
#
# Measurement: S13_D21d2 HbO
# Channel Index: 577
# Chromophore Index: 0
#
# Measurement: S13_D21d2 HbR
# Channel Index: 577
# Chromophore Index: 1
#
# Measurement: S13_D21d3 HbO
# Channel Index: 578
# Chromophore Index: 0
#
# Measurement: S13_D21d3 HbR
# Channel Index: 578
# Chromophore Index: 1
#
# Measurement: S13_D21d4 HbO
# Channel Index: 579
# Chromophore Index: 0
#
# Measurement: S13_D21d4 HbR
# Channel Index: 579
# Chromophore Index: 1
#
# Measurement: S13_D21d5 HbO
# Channel Index: 580
# Chromophore Index: 0
#
# Measurement: S13_D21d5 HbR
# Channel Index: 580
# Chromophore Index: 1
#
# Measurement: S13_D21d0 HbO
# Channel Index: 575
# Chromophore Index: 0
#
# Measurement: S13_D21d0 HbR
# Channel Index: 575
# Chromophore Index: 1
#
# Measurement: S13_D23d1 HbO
# Channel Index: 582
# Chromophore Index: 0
#
# Measurement: S13_D23d1 HbR
# Channel Index: 582
# Chromophore Index: 1
#
# Measurement: S13_D23d2 HbO
# Channel Index: 583
# Chromophore Index: 0
#
# Measurement: S13_D23d2 HbR
# Channel Index: 583
# Chromophore Index: 1
#
# Measurement: S13_D23d5 HbO
# Channel Index: 584
# Chromophore Index: 0
#
# Measurement: S13_D23d5 HbR
# Channel Index: 584
# Chromophore Index: 1
#
# Measurement: S13_D23d0 HbO
# Channel Index: 581
# Chromophore Index: 0
#
# Measurement: S13_D23d0 HbR
# Channel Index: 581
# Chromophore Index: 1
#
# Measurement: S13_D29d1 HbO
# Channel Index: 585
# Chromophore Index: 0
#
# Measurement: S13_D29d1 HbR
# Channel Index: 585
# Chromophore Index: 1
#
# Measurement: S13_D12d1 HbO
# Channel Index: 555
# Chromophore Index: 0
#
# Measurement: S13_D12d1 HbR
# Channel Index: 555
# Chromophore Index: 1
#
# Measurement: S13_D12d0 HbO
# Channel Index: 554
# Chromophore Index: 0
#
# Measurement: S13_D12d0 HbR
# Channel Index: 554
# Chromophore Index: 1
#
# Measurement: S13_D12d5 HbO
# Channel Index: 559
# Chromophore Index: 0
#
# Measurement: S13_D12d5 HbR
# Channel Index: 559
# Chromophore Index: 1
#
# Measurement: S13_D12d4 HbO
# Channel Index: 558
# Chromophore Index: 0
#
# Measurement: S13_D12d4 HbR
# Channel Index: 558
# Chromophore Index: 1
#
# Measurement: S13_D12d3 HbO
# Channel Index: 557
# Chromophore Index: 0
#
# Measurement: S13_D12d3 HbR
# Channel Index: 557
# Chromophore Index: 1
#
# Measurement: S13_D12d2 HbO
# Channel Index: 556
# Chromophore Index: 0
#
# Measurement: S13_D12d2 HbR
# Channel Index: 556
# Chromophore Index: 1
#
# Measurement: S13_D20d1 HbO
# Channel Index: 572
# Chromophore Index: 0
#
# Measurement: S13_D20d1 HbR
# Channel Index: 572
# Chromophore Index: 1
#
# Measurement: S13_D20d3 HbO
# Channel Index: 574
# Chromophore Index: 0
#
# Measurement: S13_D20d3 HbR
# Channel Index: 574
# Chromophore Index: 1
#
# Measurement: S13_D20d2 HbO
# Channel Index: 573
# Chromophore Index: 0
#
# Measurement: S13_D20d2 HbR
# Channel Index: 573
# Chromophore Index: 1
#
# Measurement: S15_D07d2 HbO
# Channel Index: 633
# Chromophore Index: 0
#
# Measurement: S15_D07d2 HbR
# Channel Index: 633
# Chromophore Index: 1
#
# Measurement: S15_D11d4 HbO
# Channel Index: 636
# Chromophore Index: 0
#
# Measurement: S15_D11d4 HbR
# Channel Index: 636
# Chromophore Index: 1
#
# Measurement: S15_D11d5 HbO
# Channel Index: 637
# Chromophore Index: 0
#
# Measurement: S15_D11d5 HbR
# Channel Index: 637
# Chromophore Index: 1
#
# Measurement: S15_D11d0 HbO
# Channel Index: 634
# Chromophore Index: 0
#
# Measurement: S15_D11d0 HbR
# Channel Index: 634
# Chromophore Index: 1
#
# Measurement: S15_D11d1 HbO
# Channel Index: 635
# Chromophore Index: 0
#
# Measurement: S15_D11d1 HbR
# Channel Index: 635
# Chromophore Index: 1
#
# Measurement: S15_D13d1 HbO
# Channel Index: 639
# Chromophore Index: 0
#
# Measurement: S15_D13d1 HbR
# Channel Index: 639
# Chromophore Index: 1
#
# Measurement: S15_D13d2 HbO
# Channel Index: 640
# Chromophore Index: 0
#
# Measurement: S15_D13d2 HbR
# Channel Index: 640
# Chromophore Index: 1
#
# Measurement: S15_D13d3 HbO
# Channel Index: 641
# Chromophore Index: 0
#
# Measurement: S15_D13d3 HbR
# Channel Index: 641
# Chromophore Index: 1
#
# Measurement: S15_D13d4 HbO
# Channel Index: 642
# Chromophore Index: 0
#
# Measurement: S15_D13d4 HbR
# Channel Index: 642
# Chromophore Index: 1
#
# Measurement: S15_D13d5 HbO
# Channel Index: 643
# Chromophore Index: 0
#
# Measurement: S15_D13d5 HbR
# Channel Index: 643
# Chromophore Index: 1
#
# Measurement: S15_D13d0 HbO
# Channel Index: 638
# Chromophore Index: 0
#
# Measurement: S15_D13d0 HbR
# Channel Index: 638
# Chromophore Index: 1
#
# Measurement: S15_D15d0 HbO
# Channel Index: 644
# Chromophore Index: 0
#
# Measurement: S15_D15d0 HbR
# Channel Index: 644
# Chromophore Index: 1
#
# Measurement: S15_D15d1 HbO
# Channel Index: 645
# Chromophore Index: 0
#
# Measurement: S15_D15d1 HbR
# Channel Index: 645
# Chromophore Index: 1
#
# Measurement: S15_D15d2 HbO
# Channel Index: 646
# Chromophore Index: 0
#
# Measurement: S15_D15d2 HbR
# Channel Index: 646
# Chromophore Index: 1
#
# Measurement: S15_D15d3 HbO
# Channel Index: 647
# Chromophore Index: 0
#
# Measurement: S15_D15d3 HbR
# Channel Index: 647
# Chromophore Index: 1
#
# Measurement: S15_D15d4 HbO
# Channel Index: 648
# Chromophore Index: 0
#
# Measurement: S15_D15d4 HbR
# Channel Index: 648
# Chromophore Index: 1
#
# Measurement: S15_D15d5 HbO
# Channel Index: 649
# Chromophore Index: 0
#
# Measurement: S15_D15d5 HbR
# Channel Index: 649
# Chromophore Index: 1
#
# Measurement: S15_D21d1 HbO
# Channel Index: 657
# Chromophore Index: 0
#
# Measurement: S15_D21d1 HbR
# Channel Index: 657
# Chromophore Index: 1
#
# Measurement: S15_D21d2 HbO
# Channel Index: 658
# Chromophore Index: 0
#
# Measurement: S15_D21d2 HbR
# Channel Index: 658
# Chromophore Index: 1
#
# Measurement: S15_D21d3 HbO
# Channel Index: 659
# Chromophore Index: 0
#
# Measurement: S15_D21d3 HbR
# Channel Index: 659
# Chromophore Index: 1
#
# Measurement: S15_D21d4 HbO
# Channel Index: 660
# Chromophore Index: 0
#
# Measurement: S15_D21d4 HbR
# Channel Index: 660
# Chromophore Index: 1
#
# Measurement: S15_D21d5 HbO
# Channel Index: 661
# Chromophore Index: 0
#
# Measurement: S15_D21d5 HbR
# Channel Index: 661
# Chromophore Index: 1
#
# Measurement: S15_D21d0 HbO
# Channel Index: 656
# Chromophore Index: 0
#
# Measurement: S15_D21d0 HbR
# Channel Index: 656
# Chromophore Index: 1
#
# Measurement: S15_D23d1 HbO
# Channel Index: 663
# Chromophore Index: 0
#
# Measurement: S15_D23d1 HbR
# Channel Index: 663
# Chromophore Index: 1
#
# Measurement: S15_D23d2 HbO
# Channel Index: 664
# Chromophore Index: 0
#
# Measurement: S15_D23d2 HbR
# Channel Index: 664
# Chromophore Index: 1
#
# Measurement: S15_D23d3 HbO
# Channel Index: 665
# Chromophore Index: 0
#
# Measurement: S15_D23d3 HbR
# Channel Index: 665
# Chromophore Index: 1
#
# Measurement: S15_D23d4 HbO
# Channel Index: 666
# Chromophore Index: 0
#
# Measurement: S15_D23d4 HbR
# Channel Index: 666
# Chromophore Index: 1
#
# Measurement: S15_D23d5 HbO
# Channel Index: 667
# Chromophore Index: 0
#
# Measurement: S15_D23d5 HbR
# Channel Index: 667
# Chromophore Index: 1
#
# Measurement: S15_D23d0 HbO
# Channel Index: 662
# Chromophore Index: 0
#
# Measurement: S15_D23d0 HbR
# Channel Index: 662
# Chromophore Index: 1
#
# Measurement: S15_D29d1 HbO
# Channel Index: 674
# Chromophore Index: 0
#
# Measurement: S15_D29d1 HbR
# Channel Index: 674
# Chromophore Index: 1
#
# Measurement: S15_D29d2 HbO
# Channel Index: 675
# Chromophore Index: 0
#
# Measurement: S15_D29d2 HbR
# Channel Index: 675
# Chromophore Index: 1
#
# Measurement: S15_D29d3 HbO
# Channel Index: 676
# Chromophore Index: 0
#
# Measurement: S15_D29d3 HbR
# Channel Index: 676
# Chromophore Index: 1
#
# Measurement: S15_D29d0 HbO
# Channel Index: 673
# Chromophore Index: 0
#
# Measurement: S15_D29d0 HbR
# Channel Index: 673
# Chromophore Index: 1
#
# Measurement: S15_D31d2 HbO
# Channel Index: 678
# Chromophore Index: 0
#
# Measurement: S15_D31d2 HbR
# Channel Index: 678
# Chromophore Index: 1
#
# Measurement: S15_D31d3 HbO
# Channel Index: 679
# Chromophore Index: 0
#
# Measurement: S15_D31d3 HbR
# Channel Index: 679
# Chromophore Index: 1
#
# Measurement: S15_D31d1 HbO
# Channel Index: 677
# Chromophore Index: 0
#
# Measurement: S15_D31d1 HbR
# Channel Index: 677
# Chromophore Index: 1
#
# Measurement: S15_D17d0 HbO
# Channel Index: 650
# Chromophore Index: 0
#
# Measurement: S15_D17d0 HbR
# Channel Index: 650
# Chromophore Index: 1
#
# Measurement: S15_D17d1 HbO
# Channel Index: 651
# Chromophore Index: 0
#
# Measurement: S15_D17d1 HbR
# Channel Index: 651
# Chromophore Index: 1
#
# Measurement: S15_D17d2 HbO
# Channel Index: 652
# Chromophore Index: 0
#
# Measurement: S15_D17d2 HbR
# Channel Index: 652
# Chromophore Index: 1
#
# Measurement: S15_D17d3 HbO
# Channel Index: 653
# Chromophore Index: 0
#
# Measurement: S15_D17d3 HbR
# Channel Index: 653
# Chromophore Index: 1
#
# Measurement: S15_D17d4 HbO
# Channel Index: 654
# Chromophore Index: 0
#
# Measurement: S15_D17d4 HbR
# Channel Index: 654
# Chromophore Index: 1
#
# Measurement: S15_D17d5 HbO
# Channel Index: 655
# Chromophore Index: 0
#
# Measurement: S15_D17d5 HbR
# Channel Index: 655
# Chromophore Index: 1
#
# Measurement: S15_D25d2 HbO
# Channel Index: 670
# Chromophore Index: 0
#
# Measurement: S15_D25d2 HbR
# Channel Index: 670
# Chromophore Index: 1
#
# Measurement: S15_D25d3 HbO
# Channel Index: 671
# Chromophore Index: 0
#
# Measurement: S15_D25d3 HbR
# Channel Index: 671
# Chromophore Index: 1
#
# Measurement: S15_D25d5 HbO
# Channel Index: 672
# Chromophore Index: 0
#
# Measurement: S15_D25d5 HbR
# Channel Index: 672
# Chromophore Index: 1
#
# Measurement: S15_D25d0 HbO
# Channel Index: 668
# Chromophore Index: 0
#
# Measurement: S15_D25d0 HbR
# Channel Index: 668
# Chromophore Index: 1
#
# Measurement: S15_D25d1 HbO
# Channel Index: 669
# Chromophore Index: 0
#
# Measurement: S15_D25d1 HbR
# Channel Index: 669
# Chromophore Index: 1
#
# Measurement: S21_D13d1 HbO
# Channel Index: 900
# Chromophore Index: 0
#
# Measurement: S21_D13d1 HbR
# Channel Index: 900
# Chromophore Index: 1
#
# Measurement: S21_D13d2 HbO
# Channel Index: 901
# Chromophore Index: 0
#
# Measurement: S21_D13d2 HbR
# Channel Index: 901
# Chromophore Index: 1
#
# Measurement: S21_D13d3 HbO
# Channel Index: 902
# Chromophore Index: 0
#
# Measurement: S21_D13d3 HbR
# Channel Index: 902
# Chromophore Index: 1
#
# Measurement: S21_D13d4 HbO
# Channel Index: 903
# Chromophore Index: 0
#
# Measurement: S21_D13d4 HbR
# Channel Index: 903
# Chromophore Index: 1
#
# Measurement: S21_D13d5 HbO
# Channel Index: 904
# Chromophore Index: 0
#
# Measurement: S21_D13d5 HbR
# Channel Index: 904
# Chromophore Index: 1
#
# Measurement: S21_D13d0 HbO
# Channel Index: 899
# Chromophore Index: 0
#
# Measurement: S21_D13d0 HbR
# Channel Index: 899
# Chromophore Index: 1
#
# Measurement: S21_D15d0 HbO
# Channel Index: 905
# Chromophore Index: 0
#
# Measurement: S21_D15d0 HbR
# Channel Index: 905
# Chromophore Index: 1
#
# Measurement: S21_D15d1 HbO
# Channel Index: 906
# Chromophore Index: 0
#
# Measurement: S21_D15d1 HbR
# Channel Index: 906
# Chromophore Index: 1
#
# Measurement: S21_D15d2 HbO
# Channel Index: 907
# Chromophore Index: 0
#
# Measurement: S21_D15d2 HbR
# Channel Index: 907
# Chromophore Index: 1
#
# Measurement: S21_D15d3 HbO
# Channel Index: 908
# Chromophore Index: 0
#
# Measurement: S21_D15d3 HbR
# Channel Index: 908
# Chromophore Index: 1
#
# Measurement: S21_D15d4 HbO
# Channel Index: 909
# Chromophore Index: 0
#
# Measurement: S21_D15d4 HbR
# Channel Index: 909
# Chromophore Index: 1
#
# Measurement: S21_D15d5 HbO
# Channel Index: 910
# Chromophore Index: 0
#
# Measurement: S21_D15d5 HbR
# Channel Index: 910
# Chromophore Index: 1
#
# Measurement: S21_D21d1 HbO
# Channel Index: 918
# Chromophore Index: 0
#
# Measurement: S21_D21d1 HbR
# Channel Index: 918
# Chromophore Index: 1
#
# Measurement: S21_D21d2 HbO
# Channel Index: 919
# ...
# Channel Index: 1929
# Chromophore Index: 0
#
# Measurement: S44_D50d0 HbR
# Channel Index: 1929
# Chromophore Index: 1
#
# Measurement: S44_D50d5 HbO
# Channel Index: 1932
# Chromophore Index: 0
#
# Measurement: S44_D50d5 HbR
# Channel Index: 1932
# Chromophore Index: 1
#
# Measurement: S44_D50d4 HbO
# Channel Index: 1931
# Chromophore Index: 0
#
# Measurement: S44_D50d4 HbR
# Channel Index: 1931
# Chromophore Index: 1
#
# Measurement: S44_D50d3 HbO
# Channel Index: 1930
# Chromophore Index: 0
#
# Measurement: S44_D50d3 HbR
# Channel Index: 1930
# Chromophore Index: 1
#
# Measurement: S46_D45d2 HbO
# Channel Index: 2006
# Chromophore Index: 0
#
# Measurement: S46_D45d2 HbR
# Channel Index: 2006
# Chromophore Index: 1
#
# Measurement: S46_D45d3 HbO
# Channel Index: 2007
# Chromophore Index: 0
#
# Measurement: S46_D45d3 HbR
# Channel Index: 2007
# Chromophore Index: 1
#
# Measurement: S46_D38d3 HbO
# Channel Index: 1985
# Chromophore Index: 0
#
# Measurement: S46_D38d3 HbR
# Channel Index: 1985
# Chromophore Index: 1
#
# Measurement: S46_D38d2 HbO
# Channel Index: 1984
# Chromophore Index: 0
#
# Measurement: S46_D38d2 HbR
# Channel Index: 1984
# Chromophore Index: 1
#
# Measurement: S46_D38d1 HbO
# Channel Index: 1983
# Chromophore Index: 0
#
# Measurement: S46_D38d1 HbR
# Channel Index: 1983
# Chromophore Index: 1
#
# Measurement: S46_D38d0 HbO
# Channel Index: 1982
# Chromophore Index: 0
#
# Measurement: S46_D38d0 HbR
# Channel Index: 1982
# Chromophore Index: 1
#
# Measurement: S46_D38d5 HbO
# Channel Index: 1987
# Chromophore Index: 0
#
# Measurement: S46_D38d5 HbR
# Channel Index: 1987
# Chromophore Index: 1
#
# Measurement: S46_D38d4 HbO
# Channel Index: 1986
# Chromophore Index: 0
#
# Measurement: S46_D38d4 HbR
# Channel Index: 1986
# Chromophore Index: 1
#
# Measurement: S46_D40d2 HbO
# Channel Index: 1990
# Chromophore Index: 0
#
# Measurement: S46_D40d2 HbR
# Channel Index: 1990
# Chromophore Index: 1
#
# Measurement: S46_D40d1 HbO
# Channel Index: 1989
# Chromophore Index: 0
#
# Measurement: S46_D40d1 HbR
# Channel Index: 1989
# Chromophore Index: 1
#
# Measurement: S46_D40d0 HbO
# Channel Index: 1988
# Chromophore Index: 0
#
# Measurement: S46_D40d0 HbR
# Channel Index: 1988
# Chromophore Index: 1
#
# Measurement: S46_D40d5 HbO
# Channel Index: 1993
# Chromophore Index: 0
#
# Measurement: S46_D40d5 HbR
# Channel Index: 1993
# Chromophore Index: 1
#
# Measurement: S46_D40d4 HbO
# Channel Index: 1992
# Chromophore Index: 0
#
# Measurement: S46_D40d4 HbR
# Channel Index: 1992
# Chromophore Index: 1
#
# Measurement: S46_D40d3 HbO
# Channel Index: 1991
# Chromophore Index: 0
#
# Measurement: S46_D40d3 HbR
# Channel Index: 1991
# Chromophore Index: 1
#
# Measurement: S46_D42d5 HbO
# Channel Index: 1999
# Chromophore Index: 0
#
# Measurement: S46_D42d5 HbR
# Channel Index: 1999
# Chromophore Index: 1
#
# Measurement: S46_D42d4 HbO
# Channel Index: 1998
# Chromophore Index: 0
#
# Measurement: S46_D42d4 HbR
# Channel Index: 1998
# Chromophore Index: 1
#
# Measurement: S46_D42d3 HbO
# Channel Index: 1997
# Chromophore Index: 0
#
# Measurement: S46_D42d3 HbR
# Channel Index: 1997
# Chromophore Index: 1
#
# Measurement: S46_D42d2 HbO
# Channel Index: 1996
# Chromophore Index: 0
#
# Measurement: S46_D42d2 HbR
# Channel Index: 1996
# Chromophore Index: 1
#
# Measurement: S46_D42d1 HbO
# Channel Index: 1995
# Chromophore Index: 0
#
# Measurement: S46_D42d1 HbR
# Channel Index: 1995
# Chromophore Index: 1
#
# Measurement: S46_D42d0 HbO
# Channel Index: 1994
# Chromophore Index: 0
#
# Measurement: S46_D42d0 HbR
# Channel Index: 1994
# Chromophore Index: 1
#
# Measurement: S46_D44d3 HbO
# Channel Index: 2003
# Chromophore Index: 0
#
# Measurement: S46_D44d3 HbR
# Channel Index: 2003
# Chromophore Index: 1
#
# Measurement: S46_D44d2 HbO
# Channel Index: 2002
# Chromophore Index: 0
#
# Measurement: S46_D44d2 HbR
# Channel Index: 2002
# Chromophore Index: 1
#
# Measurement: S46_D44d1 HbO
# Channel Index: 2001
# Chromophore Index: 0
#
# Measurement: S46_D44d1 HbR
# Channel Index: 2001
# Chromophore Index: 1
#
# Measurement: S46_D44d0 HbO
# Channel Index: 2000
# Chromophore Index: 0
#
# Measurement: S46_D44d0 HbR
# Channel Index: 2000
# Chromophore Index: 1
#
# Measurement: S46_D44d5 HbO
# Channel Index: 2005
# Chromophore Index: 0
#
# Measurement: S46_D44d5 HbR
# Channel Index: 2005
# Chromophore Index: 1
#
# Measurement: S46_D44d4 HbO
# Channel Index: 2004
# Chromophore Index: 0
#
# Measurement: S46_D44d4 HbR
# Channel Index: 2004
# Chromophore Index: 1
#
# Measurement: S46_D46d2 HbO
# Channel Index: 2010
# Chromophore Index: 0
#
# Measurement: S46_D46d2 HbR
# Channel Index: 2010
# Chromophore Index: 1
#
# Measurement: S46_D46d1 HbO
# Channel Index: 2009
# Chromophore Index: 0
#
# Measurement: S46_D46d1 HbR
# Channel Index: 2009
# Chromophore Index: 1
#
# Measurement: S46_D46d0 HbO
# Channel Index: 2008
# Chromophore Index: 0
#
# Measurement: S46_D46d0 HbR
# Channel Index: 2008
# Chromophore Index: 1
#
# Measurement: S46_D46d5 HbO
# Channel Index: 2013
# Chromophore Index: 0
#
# Measurement: S46_D46d5 HbR
# Channel Index: 2013
# Chromophore Index: 1
#
# Measurement: S46_D46d4 HbO
# Channel Index: 2012
# Chromophore Index: 0
#
# Measurement: S46_D46d4 HbR
# Channel Index: 2012
# Chromophore Index: 1
#
# Measurement: S46_D46d3 HbO
# Channel Index: 2011
# Chromophore Index: 0
#
# Measurement: S46_D46d3 HbR
# Channel Index: 2011
# Chromophore Index: 1
#
# Measurement: S46_D48d3 HbO
# Channel Index: 2017
# Chromophore Index: 0
#
# Measurement: S46_D48d3 HbR
# Channel Index: 2017
# Chromophore Index: 1
#
# Measurement: S46_D48d2 HbO
# Channel Index: 2016
# Chromophore Index: 0
#
# Measurement: S46_D48d2 HbR
# Channel Index: 2016
# Chromophore Index: 1
#
# Measurement: S46_D48d1 HbO
# Channel Index: 2015
# Chromophore Index: 0
#
# Measurement: S46_D48d1 HbR
# Channel Index: 2015
# Chromophore Index: 1
#
# Measurement: S46_D48d0 HbO
# Channel Index: 2014
# Chromophore Index: 0
#
# Measurement: S46_D48d0 HbR
# Channel Index: 2014
# Chromophore Index: 1
#
# Measurement: S46_D48d5 HbO
# Channel Index: 2019
# Chromophore Index: 0
#
# Measurement: S46_D48d5 HbR
# Channel Index: 2019
# Chromophore Index: 1
#
# Measurement: S46_D48d4 HbO
# Channel Index: 2018
# Chromophore Index: 0
#
# Measurement: S46_D48d4 HbR
# Channel Index: 2018
# Chromophore Index: 1
#
# Measurement: S46_D50d2 HbO
# Channel Index: 2022
# Chromophore Index: 0
#
# Measurement: S46_D50d2 HbR
# Channel Index: 2022
# Chromophore Index: 1
#
# Measurement: S46_D50d1 HbO
# Channel Index: 2021
# Chromophore Index: 0
#
# Measurement: S46_D50d1 HbR
# Channel Index: 2021
# Chromophore Index: 1
#
# Measurement: S46_D50d0 HbO
# Channel Index: 2020
# Chromophore Index: 0
#
# Measurement: S46_D50d0 HbR
# Channel Index: 2020
# Chromophore Index: 1
#
# Measurement: S46_D50d5 HbO
# Channel Index: 2025
# Chromophore Index: 0
#
# Measurement: S46_D50d5 HbR
# Channel Index: 2025
# Chromophore Index: 1
#
# Measurement: S46_D50d4 HbO
# Channel Index: 2024
# Chromophore Index: 0
#
# Measurement: S46_D50d4 HbR
# Channel Index: 2024
# Chromophore Index: 1
#
# Measurement: S46_D50d3 HbO
# Channel Index: 2023
# Chromophore Index: 0
#
# Measurement: S46_D50d3 HbR
# Channel Index: 2023
# Chromophore Index: 1
#
# Measurement: S48_D45d0 HbO
# Channel Index: 2081
# Chromophore Index: 0
#
# Measurement: S48_D45d0 HbR
# Channel Index: 2081
# Chromophore Index: 1
#
# Measurement: S48_D45d1 HbO
# Channel Index: 2082
# Chromophore Index: 0
#
# Measurement: S48_D45d1 HbR
# Channel Index: 2082
# Chromophore Index: 1
#
# Measurement: S48_D45d2 HbO
# Channel Index: 2083
# Chromophore Index: 0
#
# Measurement: S48_D45d2 HbR
# Channel Index: 2083
# Chromophore Index: 1
#
# Measurement: S48_D45d3 HbO
# Channel Index: 2084
# Chromophore Index: 0
#
# Measurement: S48_D45d3 HbR
# Channel Index: 2084
# Chromophore Index: 1
#
# Measurement: S48_D49d1 HbO
# Channel Index: 2097
# Chromophore Index: 0
#
# Measurement: S48_D49d1 HbR
# Channel Index: 2097
# Chromophore Index: 1
#
# Measurement: S48_D49d2 HbO
# Channel Index: 2098
# Chromophore Index: 0
#
# Measurement: S48_D49d2 HbR
# Channel Index: 2098
# Chromophore Index: 1
#
# Measurement: S48_D40d1 HbO
# Channel Index: 2071
# Chromophore Index: 0
#
# Measurement: S48_D40d1 HbR
# Channel Index: 2071
# Chromophore Index: 1
#
# Measurement: S48_D40d0 HbO
# Channel Index: 2070
# Chromophore Index: 0
#
# Measurement: S48_D40d0 HbR
# Channel Index: 2070
# Chromophore Index: 1
#
# Measurement: S48_D40d5 HbO
# Channel Index: 2073
# Chromophore Index: 0
#
# Measurement: S48_D40d5 HbR
# Channel Index: 2073
# Chromophore Index: 1
#
# Measurement: S48_D40d4 HbO
# Channel Index: 2072
# Chromophore Index: 0
#
# Measurement: S48_D40d4 HbR
# Channel Index: 2072
# Chromophore Index: 1
#
# Measurement: S48_D42d3 HbO
# Channel Index: 2074
# Chromophore Index: 0
#
# Measurement: S48_D42d3 HbR
# Channel Index: 2074
# Chromophore Index: 1
#
# Measurement: S48_D44d3 HbO
# Channel Index: 2078
# Chromophore Index: 0
#
# Measurement: S48_D44d3 HbR
# Channel Index: 2078
# Chromophore Index: 1
#
# Measurement: S48_D44d2 HbO
# Channel Index: 2077
# Chromophore Index: 0
#
# Measurement: S48_D44d2 HbR
# Channel Index: 2077
# Chromophore Index: 1
#
# Measurement: S48_D44d1 HbO
# Channel Index: 2076
# Chromophore Index: 0
#
# Measurement: S48_D44d1 HbR
# Channel Index: 2076
# Chromophore Index: 1
#
# Measurement: S48_D44d0 HbO
# Channel Index: 2075
# Chromophore Index: 0
#
# Measurement: S48_D44d0 HbR
# Channel Index: 2075
# Chromophore Index: 1
#
# Measurement: S48_D44d5 HbO
# Channel Index: 2080
# Chromophore Index: 0
#
# Measurement: S48_D44d5 HbR
# Channel Index: 2080
# Chromophore Index: 1
#
# Measurement: S48_D44d4 HbO
# Channel Index: 2079
# Chromophore Index: 0
#
# Measurement: S48_D44d4 HbR
# Channel Index: 2079
# Chromophore Index: 1
#
# Measurement: S48_D46d2 HbO
# Channel Index: 2087
# Chromophore Index: 0
#
# Measurement: S48_D46d2 HbR
# Channel Index: 2087
# Chromophore Index: 1
#
# Measurement: S48_D46d1 HbO
# Channel Index: 2086
# Chromophore Index: 0
#
# Measurement: S48_D46d1 HbR
# Channel Index: 2086
# Chromophore Index: 1
#
# Measurement: S48_D46d0 HbO
# Channel Index: 2085
# Chromophore Index: 0
#
# Measurement: S48_D46d0 HbR
# Channel Index: 2085
# Chromophore Index: 1
#
# Measurement: S48_D46d5 HbO
# Channel Index: 2090
# Chromophore Index: 0
#
# Measurement: S48_D46d5 HbR
# Channel Index: 2090
# Chromophore Index: 1
#
# Measurement: S48_D46d4 HbO
# Channel Index: 2089
# Chromophore Index: 0
#
# Measurement: S48_D46d4 HbR
# Channel Index: 2089
# Chromophore Index: 1
#
# Measurement: S48_D46d3 HbO
# Channel Index: 2088
# Chromophore Index: 0
#
# Measurement: S48_D46d3 HbR
# Channel Index: 2088
# Chromophore Index: 1
#
# Measurement: S48_D48d3 HbO
# Channel Index: 2094
# Chromophore Index: 0
#
# Measurement: S48_D48d3 HbR
# Channel Index: 2094
# Chromophore Index: 1
#
# Measurement: S48_D48d2 HbO
# Channel Index: 2093
# Chromophore Index: 0
#
# Measurement: S48_D48d2 HbR
# Channel Index: 2093
# Chromophore Index: 1
#
# Measurement: S48_D48d1 HbO
# Channel Index: 2092
# Chromophore Index: 0
#
# Measurement: S48_D48d1 HbR
# Channel Index: 2092
# Chromophore Index: 1
#
# Measurement: S48_D48d0 HbO
# Channel Index: 2091
# Chromophore Index: 0
#
# Measurement: S48_D48d0 HbR
# Channel Index: 2091
# Chromophore Index: 1
#
# Measurement: S48_D48d5 HbO
# Channel Index: 2096
# Chromophore Index: 0
#
# Measurement: S48_D48d5 HbR
# Channel Index: 2096
# Chromophore Index: 1
#
# Measurement: S48_D48d4 HbO
# Channel Index: 2095
# Chromophore Index: 0
#
# Measurement: S48_D48d4 HbR
# Channel Index: 2095
# Chromophore Index: 1
#
# Measurement: S48_D50d2 HbO
# Channel Index: 2101
# Chromophore Index: 0
#
# Measurement: S48_D50d2 HbR
# Channel Index: 2101
# Chromophore Index: 1
#
# Measurement: S48_D50d1 HbO
# Channel Index: 2100
# Chromophore Index: 0
#
# Measurement: S48_D50d1 HbR
# Channel Index: 2100
# Chromophore Index: 1
#
# Measurement: S48_D50d0 HbO
# Channel Index: 2099
# Chromophore Index: 0
#
# Measurement: S48_D50d0 HbR
# Channel Index: 2099
# Chromophore Index: 1
#
# Measurement: S48_D50d5 HbO
# Channel Index: 2104
# Chromophore Index: 0
#
# Measurement: S48_D50d5 HbR
# Channel Index: 2104
# Chromophore Index: 1
#
# Measurement: S48_D50d4 HbO
# Channel Index: 2103
# Chromophore Index: 0
#
# Measurement: S48_D50d4 HbR
# Channel Index: 2103
# Chromophore Index: 1
#
# Measurement: S48_D50d3 HbO
# Channel Index: 2102
# Chromophore Index: 0
#
# Measurement: S48_D50d3 HbR
# Channel Index: 2102
# Chromophore Index: 1
#
# Measurement: S50_D38d3 HbO
# Channel Index: 2143
# Chromophore Index: 0
#
# Measurement: S50_D38d3 HbR
# Channel Index: 2143
# Chromophore Index: 1
#
# Measurement: S50_D38d2 HbO
# Channel Index: 2142
# Chromophore Index: 0
#
# Measurement: S50_D38d2 HbR
# Channel Index: 2142
# Chromophore Index: 1
#
# Measurement: S50_D38d1 HbO
# Channel Index: 2141
# Chromophore Index: 0
#
# Measurement: S50_D38d1 HbR
# Channel Index: 2141
# Chromophore Index: 1
#
# Measurement: S50_D38d0 HbO
# Channel Index: 2140
# Chromophore Index: 0
#
# Measurement: S50_D38d0 HbR
# Channel Index: 2140
# Chromophore Index: 1
#
# Measurement: S50_D38d5 HbO
# Channel Index: 2145
# Chromophore Index: 0
#
# Measurement: S50_D38d5 HbR
# Channel Index: 2145
# Chromophore Index: 1
#
# Measurement: S50_D38d4 HbO
# Channel Index: 2144
# Chromophore Index: 0
#
# Measurement: S50_D38d4 HbR
# Channel Index: 2144
# Chromophore Index: 1
#
# Measurement: S50_D40d0 HbO
# Channel Index: 2146
# Chromophore Index: 0
#
# Measurement: S50_D40d0 HbR
# Channel Index: 2146
# Chromophore Index: 1
#
# Measurement: S50_D42d5 HbO
# Channel Index: 2150
# Chromophore Index: 0
#
# Measurement: S50_D42d5 HbR
# Channel Index: 2150
# Chromophore Index: 1
#
# Measurement: S50_D42d4 HbO
# Channel Index: 2149
# Chromophore Index: 0
#
# Measurement: S50_D42d4 HbR
# Channel Index: 2149
# Chromophore Index: 1
#
# Measurement: S50_D42d3 HbO
# Channel Index: 2148
# Chromophore Index: 0
#
# Measurement: S50_D42d3 HbR
# Channel Index: 2148
# Chromophore Index: 1
#
# Measurement: S50_D42d2 HbO
# Channel Index: 2147
# Chromophore Index: 0
#
# Measurement: S50_D42d2 HbR
# Channel Index: 2147
# Chromophore Index: 1
#
# Measurement: S50_D44d3 HbO
# Channel Index: 2153
# Chromophore Index: 0
#
# Measurement: S50_D44d3 HbR
# Channel Index: 2153
# Chromophore Index: 1
#
# Measurement: S50_D44d2 HbO
# Channel Index: 2152
# Chromophore Index: 0
#
# Measurement: S50_D44d2 HbR
# Channel Index: 2152
# Chromophore Index: 1
#
# Measurement: S50_D44d1 HbO
# Channel Index: 2151
# Chromophore Index: 0
#
# Measurement: S50_D44d1 HbR
# Channel Index: 2151
# Chromophore Index: 1
#
# Measurement: S50_D44d4 HbO
# Channel Index: 2154
# Chromophore Index: 0
#
# Measurement: S50_D44d4 HbR
# Channel Index: 2154
# Chromophore Index: 1
#
# Measurement: S50_D46d2 HbO
# Channel Index: 2157
# Chromophore Index: 0
#
# Measurement: S50_D46d2 HbR
# Channel Index: 2157
# Chromophore Index: 1
#
# Measurement: S50_D46d1 HbO
# Channel Index: 2156
# Chromophore Index: 0
#
# Measurement: S50_D46d1 HbR
# Channel Index: 2156
# Chromophore Index: 1
#
# Measurement: S50_D46d0 HbO
# Channel Index: 2155
# Chromophore Index: 0
#
# Measurement: S50_D46d0 HbR
# Channel Index: 2155
# Chromophore Index: 1
#
# Measurement: S50_D46d5 HbO
# Channel Index: 2160
# Chromophore Index: 0
#
# Measurement: S50_D46d5 HbR
# Channel Index: 2160
# Chromophore Index: 1
#
# Measurement: S50_D46d4 HbO
# Channel Index: 2159
# Chromophore Index: 0
#
# Measurement: S50_D46d4 HbR
# Channel Index: 2159
# Chromophore Index: 1
#
# Measurement: S50_D46d3 HbO
# Channel Index: 2158
# Chromophore Index: 0
#
# Measurement: S50_D46d3 HbR
# Channel Index: 2158
# Chromophore Index: 1
#
# Measurement: S50_D48d3 HbO
# Channel Index: 2164
# Chromophore Index: 0
#
# Measurement: S50_D48d3 HbR
# Channel Index: 2164
# Chromophore Index: 1
#
# Measurement: S50_D48d2 HbO
# Channel Index: 2163
# Chromophore Index: 0
#
# Measurement: S50_D48d2 HbR
# Channel Index: 2163
# Chromophore Index: 1
#
# Measurement: S50_D48d1 HbO
# Channel Index: 2162
# Chromophore Index: 0
#
# Measurement: S50_D48d1 HbR
# Channel Index: 2162
# Chromophore Index: 1
#
# Measurement: S50_D48d0 HbO
# Channel Index: 2161
# Chromophore Index: 0
#
# Measurement: S50_D48d0 HbR
# Channel Index: 2161
# Chromophore Index: 1
#
# Measurement: S50_D48d5 HbO
# Channel Index: 2166
# Chromophore Index: 0
#
# Measurement: S50_D48d5 HbR
# Channel Index: 2166
# Chromophore Index: 1
#
# Measurement: S50_D48d4 HbO
# Channel Index: 2165
# Chromophore Index: 0
#
# Measurement: S50_D48d4 HbR
# Channel Index: 2165
# Chromophore Index: 1
#
# Measurement: S50_D50d2 HbO
# Channel Index: 2169
# Chromophore Index: 0
#
# Measurement: S50_D50d2 HbR
# Channel Index: 2169
# Chromophore Index: 1
#
# Measurement: S50_D50d1 HbO
# Channel Index: 2168
# Chromophore Index: 0
#
# Measurement: S50_D50d1 HbR
# Channel Index: 2168
# Chromophore Index: 1
#
# Measurement: S50_D50d0 HbO
# Channel Index: 2167
# Chromophore Index: 0
#
# Measurement: S50_D50d0 HbR
# Channel Index: 2167
# Chromophore Index: 1
#
# Measurement: S50_D50d5 HbO
# Channel Index: 2172
# Chromophore Index: 0
#
# Measurement: S50_D50d5 HbR
# Channel Index: 2172
# Chromophore Index: 1
#
# Measurement: S50_D50d4 HbO
# Channel Index: 2171
# Chromophore Index: 0
#
# Measurement: S50_D50d4 HbR
# Channel Index: 2171
# Chromophore Index: 1
#
# Measurement: S50_D50d3 HbO
# Channel Index: 2170
# Chromophore Index: 0
#
# Measurement: S50_D50d3 HbR
# Channel Index: 2170
# Chromophore Index: 1

# %%
def reshape_data(data_nirs, measurement_names, include_missing=False):
    """
    Reshape the NIRS data based on the channel and chromophore dimensions.

    Parameters
    ----------
    data_nirs : np.ndarray
        NIRS data array of shape (time, measurements)
    measurement_names : List[str]
        List of measurement names corresponding to the measurements dimension
    include_missing : bool, optional
        Flag indicating whether to include channels with missing data (NaN), by default False

    Returns
    -------
    reshaped_data : np.ndarray
        Reshaped NIRS data array of shape (time, channel, chromophore)
    channel_names : List[str]
        List of channel names corresponding to the channel dimension
    chromophore_names : List[str]
        List of chromophore names corresponding to the chromophore dimension
    """

    # Extract unique channel and chromophore names
    channel_names = sorted(list(set([name.split()[0] for name in measurement_names])))
    chromophore_names = sorted(list(set([name.split()[-1] for name in measurement_names])))

    # Determine channels to include
    channels_to_include = []
    if not include_missing:
        for channel in channel_names:
            channel_idx = [idx for idx, name in enumerate(measurement_names) if name.startswith(channel)]
            if not np.isnan(data_nirs[:, channel_idx]).all():
                channels_to_include.extend(channel_idx)
    else:
        channels_to_include = range(data_nirs.shape[1])

    # Reshape the data
    reshaped_data = data_nirs[:, channels_to_include].reshape(data_nirs.shape[0], len(channel_names), len(chromophore_names))

    return reshaped_data, channel_names, chromophore_names

# %%
# Call the reshape_data function
reshaped_data, channel_names, chromophore_names = reshape_data(data_nirs, measurement_names, include_missing=False)

# Output the results
print("Reshaped Data Shape:", reshaped_data.shape)
print("Channel Names:", channel_names)
print("Chromophore Names:", chromophore_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Call the reshape_data function
# ----> 2 reshaped_data, channel_names, chromophore_names = reshape_data(data_nirs, measurement_names, include_missing=False)
#       4 # Output the results
#       5 print("Reshaped Data Shape:", reshaped_data.shape)
#
# Cell In[11], line 39, in reshape_data(data_nirs, measurement_names, include_missing)
#      36     channels_to_include = range(data_nirs.shape[1])
#      38 # Reshape the data
# ---> 39 reshaped_data = data_nirs[:, channels_to_include].reshape(data_nirs.shape[0], len(channel_names), len(chromophore_names))
#      41 return reshaped_data, channel_names, chromophore_names
#
# ValueError: cannot reshape array of size 12228400 into shape (6436,2206,2)
